# %% [markdown]
# Examples of use of the class BayesianOptimization
#         - forrester (1d)
#         - branin (2d))
#         - gSobol (arbitrary dimension)

# %%
# %pylab inline  
# load packages and set seed
import GPy
import GPyOpt
from numpy.random import seed
seed(1)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
bounds = [(0,1)]


# starts the optimization 
myBopt = GPyOpt.methods.BayesianOptimization(f=PhyicalExperiment,
                                             bounds=bounds,
                                             X = np.array([[0.1],[0.9],[0.5]]),
                                             Y = np.array([[3],[3],[-1]]),
                                             acquisition='LCB',
                                             acquisition_par=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e0ee9a2de8ec> in <module>()
#       3
#       4 # starts the optimization
# ----> 5 myBopt = GPyOpt.methods.BayesianOptimization(f=PhyicalExperiment,
#       6                                              bounds=bounds,
#       7                                              X = np.array([[0.1],[0.9],[0.5]]),
#
# NameError: name 'PhyicalExperiment' is not defined

# %%
myBopt.start_optimization(max_iter = 0, 
                          n_inbatch = 1,
                          acqu_optimize_method = 'brute', 
                          acqu_optimize_restarts = 20, 
                          stop_criteria=-1)
# Out:
# *Optimization completed:
#    -Maximum number of iterations reached.
# array([ 0.5])

# %%
myBopt.plot_acquisition()
myBopt.start_optimization(max_iter = 1)
# Out:
# Experimental conditions:
# [ 0.49999507]
# Insert experimental value:3
# *Optimization completed:
#    -Maximum number of iterations reached.
# array([ 0.5])

# %%
class PhysicalExperiment: 
    def __init__(self):
        pass
    
    def PhysicalExperiment(X):
        n, p = X.shape
        if n==1:
            print 'Experimental conditions:'
            print X
            feval = input('Insert here experimental value:')
            output =np.array([[feval]])
    
        else:
            output = np.zeros(n).T    
            print 'Batch of %s samples is requiered:' %n
            print '---------------------------------'
            for k in range(n):
                print 'Experimental conditions for sample %s: '%k+!'
                print X[k,]
                output[k] = input('Insert experimental value:')
        return output
# Out:
#   File "<ipython-input-16-8347e26b3a15>", line 18
#     print 'Experimental conditions for sample %s: '%k+'
#                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
PhysicalExperiment(np.array([[3,1],[4,1]]))
# Out:
# Experimental conditions:
# [[3 1]
#  [4 1]]
# Batch of 2 samples is requiered:
# Insert experimental value for sample 0: 2
# Insert experimental value for sample 1: 44
# array([  2.,  44.])
