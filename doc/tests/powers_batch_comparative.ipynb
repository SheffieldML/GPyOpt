# %%
# %pylab inline  
import GPy
import GPyOpt
from numpy.random import seed
from scipy.stats import norm
import scipy
from pylab import savefig
seed(123)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# create the object function
f_true = GPyOpt.fmodels.experiments2d.powers()
f_sim = GPyOpt.fmodels.experiments2d.powers(sd= 0.1)
f_true.plot()
bounds = f_true.bounds

# %%
# create object
acquisition_name = 'LCB'
acquisition_par = 2
max_iter = 10
batch_method = 'adaptive'
n_inbatch = 5
acqu_optimize_method = 'random' 
acqu_optimize_restarts = 6


myBopt = GPyOpt.methods.BayesianOptimization(f=f_sim.f,
                                             bounds=bounds,
                                             acquisition=acquisition_name,
                                             acquisition_par=acquisition_par)

myBopt.start_optimization(max_iter = max_iter, 
                          batch_method = batch_method,
                          n_inbatch=n_inbatch, 
                          acqu_optimize_method=acqu_optimize_method,
                          acqu_optimize_restarts=acqu_optimize_restarts,
                          stop_criteria = -1)
# Out:
# *Optimization completed:
#    -Maximum number of iterations reached.
# array([ 0.0549681 ,  0.02120428])

# %%
myBopt.plot_convergence()
myBopt.plot_acquisition()
#savefig('acquisition.jpeg')

# %%
## Edit this cell
# create object
acquisition_name = 'LCB'
acquisition_par = 2
max_iter = 15
n_inbatch = 5
acqu_optimize_method = 'random' 
acqu_optimize_restarts = 25
model_data_init = 3
NR = 30


# matrices to save the results
best_sequential = np.zeros((NR,model_data_init+max_iter*n_inbatch+1))
best_random = np.zeros((NR,model_data_init+max_iter*n_inbatch+1))
best_predmean = np.zeros((NR,model_data_init+max_iter*n_inbatch+1))
best_adaptive = np.zeros((NR,model_data_init+max_iter*n_inbatch+1))

best_sequential[best_sequential==0]= np.nan
best_random[best_random==0] = np.nan
best_predmean[best_predmean==0] = np.nan
best_adaptive[best_adaptive==0] = np.nan


for k in range(NR):
    print k
    # create to BayesOpt objects
    LCB_sequential = GPyOpt.methods.BayesianOptimization(f_sim.f, bounds=bounds, acquisition=acquisition_name, acquisition_par = acquisition_par)
    LCB_random = GPyOpt.methods.BayesianOptimization(f_sim.f, X = LCB_sequential.X, Y = LCB_sequential.Y, bounds=bounds,acquisition=acquisition_name, acquisition_par = acquisition_par)
    LCB_predmean = GPyOpt.methods.BayesianOptimization(f_sim.f, X = LCB_sequential.X, Y = LCB_sequential.Y, bounds=bounds,acquisition=acquisition_name, acquisition_par = acquisition_par)
    LCB_adaptive = GPyOpt.methods.BayesianOptimization(f_sim.f, X = LCB_sequential.X, Y = LCB_sequential.Y, bounds=bounds,acquisition=acquisition_name, acquisition_par = acquisition_par)

    # run the BayesOpt loop
    LCB_sequential.start_optimization(max_iter = n_inbatch*max_iter, batch_method = 'random', n_inbatch=1, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
    LCB_random.start_optimization(max_iter = max_iter, batch_method = 'random', n_inbatch=n_inbatch, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
    LCB_predmean.start_optimization(max_iter = max_iter, batch_method = 'predmean', n_inbatch=n_inbatch, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
    LCB_adaptive.start_optimization(max_iter = max_iter, batch_method = 'adaptive', n_inbatch=n_inbatch, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
    
    # save results in a matrix
    best_sequential[k,:len(LCB_sequential.Y_best)] = LCB_sequential.Y_best 
    best_random[k,:len(LCB_random.Y_best)] = LCB_random.Y_best 
    best_predmean[k,:len(LCB_predmean.Y_best)] = LCB_predmean.Y_best 
    best_adaptive[k,:len(LCB_adaptive.Y_best)] = LCB_adaptive.Y_best
# Out:
# 0
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 1
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 2
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 3
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 4
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 5
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 6
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 7
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 8
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# 9
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# *Optimization completed:
#    -Maximum number of iterations reached.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-6d5ab9c84cfd> in <module>()
#      34     LCB_sequential.start_optimization(max_iter = n_inbatch*max_iter, batch_method = 'random', n_inbatch=1, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
#      35     LCB_random.start_optimization(max_iter = max_iter, batch_method = 'random', n_inbatch=n_inbatch, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
# ---> 36     LCB_predmean.start_optimization(max_iter = max_iter, batch_method = 'predmean', n_inbatch=n_inbatch, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
#      37     LCB_adaptive.start_optimization(max_iter = max_iter, batch_method = 'adaptive', n_inbatch=n_inbatch, acqu_optimize_method=acqu_optimize_method,acqu_optimize_restarts=acqu_optimize_restarts,stop_criteria = -1)
#      38
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in start_optimization(self, max_iter, n_inbatch, acqu_optimize_method, batch_method, acqu_optimize_restarts, alpha_L, alpha_Min, stop_criteria)
#      80
#      81
# ---> 82         return self.continue_optimization(max_iter)
#      83
#      84     def change_to_sparseGP(self, num_inducing):
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in continue_optimization(self, max_iter)
#     124                 self.s_in_min = np.vstack((self.s_in_min,np.sqrt(pred_min[1])))
#     125                 try:
# --> 126                     self._update_model()
#     127                 except np.linalg.linalg.LinAlgError:
#     128                     print 'Optimization stopped. Two equal points selected.'
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _update_model(self)
#     181             self.model.optimization_runs = [] # clear previous optimization runs so they don't get used.
#     182             self.model.optimize_restarts(num_restarts=self.model_optimize_restarts, verbose=self.verbosity)
# --> 183         self.suggested_sample = self._optimize_acquisition()
#     184
#     185     def plot_acquisition(self):
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _optimize_acquisition(self)
#     162
#     163         if self.batch_method == 'predmean':
# --> 164             X_batch = hybrid_batch_optimization(acqu_name, acquisition_par, acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#     165         elif self.batch_method == 'adaptive':
#     166             X_batch = adaptive_batch_optimization(acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch, alpha_L, alpha_Min)
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.pyc in hybrid_batch_optimization(acqu_name, acquisition_par, acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#     166                                     acqu_optimize_method = acqu_optimize_method,
#     167                                     acqu_optimize_restarts = acqu_optimize_restarts,
# --> 168                                     stop_criteria = 1e-6)
#     169
#     170         X_new = batchBO.suggested_sample
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in start_optimization(self, max_iter, n_inbatch, acqu_optimize_method, batch_method, acqu_optimize_restarts, alpha_L, alpha_Min, stop_criteria)
#      73         self.batch_method = batch_method
#      74         self.acquisition_func.model = self.model
# ---> 75         self._update_model()
#      76         prediction = self.model.predict(self.X)
#      77         self.m_in_min = prediction[0]
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _update_model(self)
#     181             self.model.optimization_runs = [] # clear previous optimization runs so they don't get used.
#     182             self.model.optimize_restarts(num_restarts=self.model_optimize_restarts, verbose=self.verbosity)
# --> 183         self.suggested_sample = self._optimize_acquisition()
#     184
#     185     def plot_acquisition(self):
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _optimize_acquisition(self)
#     162
#     163         if self.batch_method == 'predmean':
# --> 164             X_batch = hybrid_batch_optimization(acqu_name, acquisition_par, acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#     165         elif self.batch_method == 'adaptive':
#     166             X_batch = adaptive_batch_optimization(acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch, alpha_L, alpha_Min)
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.pyc in hybrid_batch_optimization(acqu_name, acquisition_par, acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#     146     kernel = model_copy.kern
#     147
# --> 148     X_new = optimize_acquisition(acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, X_batch=None, L=None, Min=None)
#     149     X_batch = reshape(X_new,input_dim)
#     150
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.pyc in optimize_acquisition(acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, X_batch, L, Min)
#     105         res = full_acquisition_optimization(acquisition,bounds,acqu_optimize_restarts, model, 'brute', X_batch, L, Min)
#     106     elif acqu_optimize_method=='random':
# --> 107         res =  full_acquisition_optimization(acquisition,bounds,acqu_optimize_restarts, model, 'random', X_batch, L, Min)
#     108     elif acqu_optimize_method=='fast_brute':
#     109         res =  fast_acquisition_optimization(acquisition,bounds,acqu_optimize_restarts, model, 'brute', X_batch, L, Min)
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.pyc in full_acquisition_optimization(acquisition, bounds, acqu_optimize_restarts, model, method_type, X_batch, L, Min)
#     132     fmins = np.zeros(acqu_optimize_restarts)
#     133     for k in range(acqu_optimize_restarts):
# --> 134         res = scipy.optimize.minimize(penalized_acquisition, x0 = samples[k,:] ,method='SLSQP',bounds=bounds, args=(acquisition, bounds, model, X_batch, L, Min))
#     135         mins[k] = res.x
#     136         fmins[k] = res.fun
#
# /usr/local/lib/python2.7/dist-packages/scipy-0.13.2-py2.7-linux-i686.egg/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     386     elif meth == 'slsqp':
#     387         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 388                                constraints, **options)
#     389     elif meth == 'dogleg':
#     390         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# /usr/local/lib/python2.7/dist-packages/scipy-0.13.2-py2.7-linux-i686.egg/scipy/optimize/slsqp.pyc in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, **unknown_options)
#     372             # Compute the derivatives of the objective function
#     373             # For some reason SLSQP wants g dimensioned to n+1
# --> 374             g = append(fprime(x),0.0)
#     375
#     376             # Compute the normals of the constraints
#
# /usr/local/lib/python2.7/dist-packages/scipy-0.13.2-py2.7-linux-i686.egg/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /usr/local/lib/python2.7/dist-packages/scipy-0.13.2-py2.7-linux-i686.egg/scipy/optimize/slsqp.pyc in approx_jacobian(x, func, epsilon, *args)
#      60     for i in range(len(x0)):
#      61         dx[i] = epsilon
# ---> 62         jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#      63         dx[i] = 0.0
#      64     return jac.transpose()
#
# /usr/local/lib/python2.7/dist-packages/scipy-0.13.2-py2.7-linux-i686.egg/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.pyc in penalized_acquisition(x, acquisition, bounds, model, X_batch, L, Min)
#      92 # creates a penalized acquisition function using 'hammer' functions around the points collected in the batch
#      93 def penalized_acquisition(x, acquisition, bounds, model, X_batch=None, L=None, Min=None):
# ---> 94     sur_min = min(-acquisition(model.X))  # assumed minimum of the minus acquisition
#      95     fval = -acquisition(x)-np.sign(sur_min)*(abs(sur_min))
#      96     if X_batch!=None:
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/acquisition.pyc in acquisition_function(self, x)
#      77                 Upper Confidence Band
#      78 		"""
# ---> 79                 m, s, fmin = get_moments(self.model, x)
#      80                 f_acqu = -m + self.acquisition_par * s
#      81                 return -f_acqu  # note: returns negative value for posterior minimization
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/util/general.pyc in get_moments(model, x)
#      55     x = reshape(x,input_dim)
#      56     fmin = min(model.predict(model.X)[0])
# ---> 57     m, v = model.predict(x)
#      58     return (m, np.sqrt(np.clip(v, 0, np.inf)), fmin)
#      59
#
# /home/javier/workspace/GitHub/GPy/GPy/core/gp.pyc in predict(self, Xnew, full_cov, Y_metadata, kern)
#     215         """
#     216         #predict the latent function values
# --> 217         mu, var = self._raw_predict(Xnew, full_cov=full_cov, kern=kern)
#     218         if self.normalizer is not None:
#     219             mu, var = self.normalizer.inverse_mean(mu), self.normalizer.inverse_variance(var)
#
# /home/javier/workspace/GitHub/GPy/GPy/core/gp.pyc in _raw_predict(self, _Xnew, full_cov, kern)
#     179             kern = self.kern
#     180
# --> 181         Kx = kern.K(_Xnew, self.X).T
#     182         WiKx = np.dot(self.posterior.woodbury_inv, Kx)
#     183         mu = np.dot(Kx.T, self.posterior.woodbury_vector)
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      63     def wrap(self, X, X2 = None, *a, **kw):
#      64         with _Slice_wrap(self, X, X2) as s:
# ---> 65             ret = f(self, s.X, s.X2, *a, **kw)
#      66         return ret
#      67     return wrap
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     178         except KeyError:
#     179             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 180         return cacher(*args, **kwargs)
#     181
#     182 class Cache_this(object):
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     104             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     105             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 106             return self.operation(*args, **kw)
#     107         # 3&4: check whether this cache_id has been cached, then has it changed?
#     108         try:
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/add.pyc in K(self, X, X2, which_parts)
#      36             # if only one part is given
#      37             which_parts = [which_parts]
# ---> 38         return reduce(np.add, (p.K(X, X2) for p in which_parts))
#      39
#      40     @Cache_this(limit=2, force_kwargs=['which_parts'])
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/add.pyc in <genexpr>((p,))
#      36             # if only one part is given
#      37             which_parts = [which_parts]
# ---> 38         return reduce(np.add, (p.K(X, X2) for p in which_parts))
#      39
#      40     @Cache_this(limit=2, force_kwargs=['which_parts'])
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      63     def wrap(self, X, X2 = None, *a, **kw):
#      64         with _Slice_wrap(self, X, X2) as s:
# ---> 65             ret = f(self, s.X, s.X2, *a, **kw)
#      66         return ret
#      67     return wrap
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     178         except KeyError:
#     179             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 180         return cacher(*args, **kwargs)
#     181
#     182 class Cache_this(object):
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     104             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     105             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 106             return self.operation(*args, **kw)
#     107         # 3&4: check whether this cache_id has been cached, then has it changed?
#     108         try:
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/stationary.pyc in K(self, X, X2)
#      80         K(X, X2) = K_of_r((X-X2)**2)
#      81         """
# ---> 82         r = self._scaled_dist(X, X2)
#      83         return self.K_of_r(r)
#      84
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     178         except KeyError:
#     179             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 180         return cacher(*args, **kwargs)
#     181
#     182 class Cache_this(object):
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     104             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     105             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 106             return self.operation(*args, **kw)
#     107         # 3&4: check whether this cache_id has been cached, then has it changed?
#     108         try:
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/stationary.pyc in _scaled_dist(self, X, X2)
#     125             return self._unscaled_dist(X/self.lengthscale, X2)
#     126         else:
# --> 127             return self._unscaled_dist(X, X2)/self.lengthscale
#     128
#     129     def Kdiag(self, X):
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/stationary.pyc in _unscaled_dist(self, X, X2)
#     104             X1sq = np.sum(np.square(X),1)
#     105             X2sq = np.sum(np.square(X2),1)
# --> 106             r2 = -2.*np.dot(X, X2.T) + X1sq[:,None] + X2sq[None,:]
#     107             r2 = np.clip(r2, 0, np.inf)
#     108             return np.sqrt(r2)
#
# KeyboardInterrupt:

# %%
# functions for plotting
def namean(dat,axis=0):
    mdat = np.ma.masked_array(dat,np.isnan(dat))
    mm = np.mean(mdat,axis=axis)
    return mm.filled(np.nan) # the desired answer

def nastd(dat,axis=0):
    mdat = np.ma.masked_array(dat,np.isnan(dat))
    mm = np.std(mdat,axis=axis)
    return mm.filled(np.nan) # the desired answer

# plots
plt.errorbar(range(max_iter*n_inbatch),namean(best_sequential[:,-(max_iter*n_inbatch):]), yerr = nastd(best_sequential[:,-(max_iter*n_inbatch):])/np.sqrt(max_iter),label='sequential')
plt.errorbar(range(max_iter*n_inbatch),namean(best_random[:,-(max_iter*n_inbatch):]), yerr = nastd(best_random[:,-(max_iter*n_inbatch):])/np.sqrt(max_iter),label='random')
plt.errorbar(range(max_iter*n_inbatch),namean(best_predmean[:,-(max_iter*n_inbatch):]), yerr = nastd(best_predmean[:,-(max_iter*n_inbatch):])/np.sqrt(max_iter),label='predmean')
plt.errorbar(range(max_iter*n_inbatch),namean(best_adaptive[:,-(max_iter*n_inbatch):]), yerr = nastd(best_adaptive[:,-(max_iter*n_inbatch):])/np.sqrt(max_iter),label='adaptive')
plt.legend()

# %%
plt.errorbar(range(max_iter*n_inbatch),namean(best_sequential[:,-(max_iter*n_inbatch):]), yerr =0,label='sequential')
plt.errorbar(range(max_iter*n_inbatch),namean(best_random[:,-(max_iter*n_inbatch):]), yerr =0,label='random')
plt.errorbar(range(max_iter*n_inbatch),namean(best_predmean[:,-(max_iter*n_inbatch):]), yerr = 0,label='predmean')
plt.errorbar(range(max_iter*n_inbatch),namean(best_adaptive[:,-(max_iter*n_inbatch):]), yerr = 0,label='adaptive')
plt.legend()
