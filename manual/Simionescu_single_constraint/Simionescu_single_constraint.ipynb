# %% [markdown]
# # Simionescu function - One constraint
#
# This is a GPyOpt contrained optimization example for the [Simionescu function with a eight-point star constraint](https://en.wikipedia.org/wiki/Test_functions_for_optimization). There are two symmetric global minima:
#
# $f(\pm 0.84852813,\mp 0.84852813) = -0.072$
#
# The important imports are the [GPy](https://sheffieldml.github.io/GPy/) and [GPyOpt](https://github.com/SheffieldML/GPyOpt) libraries, and the initial_design function to select the first points to initialize the method. This function requires dealing with constraint, which is done using the acquisition function of [Expected Improvement](https://www.researchgate.net/publication/248818761_The_application_of_Bayesian_methods_for_seeking_the_extremum) (EI) with [Probability of Feasibility](https://dl.acm.org/citation.cfm?id=3044997) (PoF). For references of Probability of Feasibility, read [Gardner et. al. (2014)](https://stat.columbia.edu/~cunningham/pdf/GardnerICML2014.pdf), [Gelbart (2015)](https://dash.harvard.edu/bitstream/handle/1/17467236/GELBART-DISSERTATION-2015.pdf?sequence=4&isAllowed=y) and [Schonlau (2015)](https://www.collectionscanada.gc.ca/obj/s4/f2/dsk3/ftp04/nq22234.pdf). A modified version of the Bayesian Optimization method is required, named ModularConstrainedBayesianOptimization.

# %%
# %pylab inline
import GPy
import GPyOpt
import numpy as np
import matplotlib.pyplot as plt
from GPyOpt.experiment_design import initial_design
from GPyOpt.acquisitions.EI_PoF import AcquisitionEI_PoF
from GPyOpt.methods import ModularConstrainedBayesianOptimization
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The definition of the Simionescu function, with star constraint, is given by the functions below:

# %%
def simionescu(x,y):
    return (0.1*x*y)

def eight_star_contraint(x,y):
    rT = 1.0
    rS = 0.2
    n = 8
    R2 = (rT + rS*np.cos( n*np.arctan2(np.array(x),np.array(y)) ))**2
    return (R2-x**2-y**2)

# %% [markdown]
# Create (xv,yv) variables to be able to plot and visualize the function in 2D and 3D

# %%
X_ax = np.linspace(-1.25,1.25,201)
Y_ax = np.linspace(-1.25,1.25,201)

xv, yv = np.meshgrid(X_ax, Y_ax, sparse=False, indexing='ij')

zv = np.zeros(xv.shape)

for i in range(X_ax.shape[0]):
    for j in range(Y_ax.shape[0]):
        g1 = eight_star_contraint(X_ax[i],Y_ax[j])
        if( (g1>=0) ):
            zv[i,j] = simionescu(X_ax[i],Y_ax[j])
        else:
            zv[i,j] = np.nan

# %% [markdown]
# To the left, the 2D heatmap plot of the Simionescu function, and to the right, a 3D rendering of the same function. There are two global minima, on the secondary diagonal.

# %%
fig = plt.figure(figsize=(16,6))

ax = fig.add_subplot(1,2,1)
ax.set_aspect('equal')
ax.grid()
ax.imshow(zv.T,cmap=cm.coolwarm,extent=(-1.25,1.25,-1.25,1.25),origin='bottom')

ax2 = fig.add_subplot(1,2,2, projection='3d')
ax2.plot_surface(xv, yv, zv, rstride=1, cstride=1,
                cmap=cm.coolwarm, edgecolor='none',
                vmin = -.1, vmax = .1)

ax2.set_title('Simionescu function with star constraint');
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('z')
plt.show()

# %% [markdown]
# The search space of the optimization problem is the box $[-1.25,1.25] \times [-1.25,1.25]$, with continuous variables.
#
# There are two GP models: One for interpolating the objective function, and another for interpolating the constraint. In this case the constraints are very simple,but it might not be the case in other problems.
#
# The acquisition function is the Expected Improvement with Probability of Feasibility extension, named AcquisitionEI_PoF. The evaluator is the standard serial evaluator. jitter is set to $10^{-3}$
#
# The initial choice of points is done via the initial_design function, according to a [Latin Hypercube](https://en.wikipedia.org/wiki/Latin_hypercube_sampling) sampling. The objective function and the constraints are evaluated on those points before the Bayesian optimization loop.

# %%
np.set_printoptions(precision=6)

objective = None 
constraint = None

space =[{'name': 'var_1', 'type': 'continuous', 'domain': (-1.25,1.25)},
        {'name': 'var_2', 'type': 'continuous', 'domain': (-1.25,1.25)}]
space = GPyOpt.Design_space(space = space)

model    = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False)
model_c1 = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False)
model_c  = [model_c1]

aquisition_optimizer = GPyOpt.optimization.AcquisitionOptimizer(space)

acquisition = AcquisitionEI_PoF(model,model_c,space,optimizer=aquisition_optimizer,
                                jitter=1e-3,jitter_c=np.array([0]))

# --- CHOOSE a collection method
evaluator = GPyOpt.core.evaluators.Sequential(acquisition)

num_init = 20
typ_init = 'latin'
X_init = initial_design(typ_init,space,num_init)

Y_init = np.zeros((X_init.shape[0],1))
C_init = np.zeros((X_init.shape[0],1))

for i in range(num_init):
    Y_init[i,0] = simionescu(X_init[i,0],X_init[i,1])
    C_init[i,0] = eight_star_contraint(X_init[i,0],X_init[i,1])
    
print(np.hstack((X_init,Y_init,C_init)))
# Out:
# [[-1.875000e-01  6.250000e-02 -1.171875e-03  6.520969e-01]
#  [ 9.375000e-01 -9.375000e-01 -8.789062e-02 -3.178125e-01]
#  [ 6.250000e-02 -1.062500e+00 -6.640625e-03  2.556006e-01]
#  [ 5.625000e-01 -3.125000e-01 -1.757813e-02  3.569494e-01]
#  [ 3.125000e-01 -4.375000e-01 -1.367187e-02  8.121875e-01]
#  [ 1.875000e-01 -6.250000e-02 -1.171875e-03  6.520969e-01]
#  [ 1.062500e+00  1.875000e-01  1.992188e-02 -9.385123e-02]
#  [-6.250000e-02 -5.625000e-01  3.515625e-03  9.489556e-01]
#  [-9.375000e-01  4.375000e-01 -4.101562e-02 -4.106057e-01]
#  [-1.187500e+00  1.187500e+00 -1.410156e-01 -1.380313e+00]
#  [-3.125000e-01 -6.875000e-01  2.148438e-02  8.145657e-02]
#  [ 6.875000e-01  9.375000e-01  6.445312e-02 -2.098602e-01]
#  [ 4.375000e-01  6.875000e-01  3.007813e-02  2.661561e-01]
#  [-8.125000e-01 -1.875000e-01  1.523438e-02  2.105374e-01]
#  [-5.625000e-01 -8.125000e-01  4.570313e-02  7.676433e-02]
#  [ 8.125000e-01  8.125000e-01  6.601563e-02  1.196875e-01]
#  [ 1.187500e+00 -1.187500e+00 -1.410156e-01 -1.380313e+00]
#  [-4.375000e-01  1.062500e+00 -4.648437e-02 -6.802677e-01]
#  [-6.875000e-01  3.125000e-01 -2.148438e-02  8.145657e-02]
#  [-1.062500e+00  5.625000e-01 -5.976563e-02 -7.157332e-01]]

# %% [markdown]
# The main external loop is executed using the ModularConstrainedBayesianOptimization object, initialized with the interpolation method of usual Gaussian Process, the acquisition function is the Expected Improvement w/ PoF, and default jitter used for a standard Bayesian Optimization loop.

# %%
iter_count = 120-num_init
current_iter = 0
X_step = X_init
Y_step = Y_init
C_step = C_init 

while current_iter < iter_count:
    bo_step = ModularConstrainedBayesianOptimization(model,
                                                     model_c,
                                                     space,
                                                     objective,
                                                     constraint,
                                                     acquisition,
                                                     evaluator,
                                                     X_init = X_step,
                                                     Y_init = Y_step,
                                                     C_init = C_step, 
                                                     normalize_Y = False)
    x_next = bo_step.suggest_next_locations()
    y_next = np.array(simionescu(x_next[0][0],x_next[0][1]))
    c1_next = eight_star_contraint(x_next[0][0],x_next[0][1])
    c_next = np.array([c1_next])
    print("Current iteration - ",current_iter," : ",np.hstack([x_next[0],y_next,c_next]))
    
    X_step = np.vstack((X_step, x_next))
    Y_step = np.vstack((Y_step, y_next))
    C_step = np.vstack((C_step, c_next))
    
    current_iter += 1
# Out:
# Current iteration -  0  :  [ 0.622961 -0.810898 -0.050516  0.166105]
# Current iteration -  1  :  [ 0.69722  -0.925428 -0.064523 -0.1598  ]
# Current iteration -  2  :  [ 0.696868 -0.907778 -0.06326  -0.099042]
# Current iteration -  3  :  [ 0.694236 -0.901762 -0.062604 -0.080286]
# Current iteration -  4  :  [ 0.885517 -0.819196 -0.072541 -0.038169]
# Current iteration -  5  :  [ 0.846266 -0.805328 -0.068152  0.065893]
# Current iteration -  6  :  [ 1.25     -0.670565 -0.083821 -1.272049]
# Current iteration -  7  :  [ 0.850728 -0.839911 -0.071454  0.010182]
# Current iteration -  8  :  [-0.745222  1.25     -0.093153 -1.271469]
# Current iteration -  9  :  [-0.869612  0.896359 -0.077948 -0.123201]
# Current iteration -  10  :  [-0.875469  0.843779 -0.07387  -0.043613]
# Current iteration -  11  :  [-0.834182  0.881418 -0.073526 -0.044326]
# Current iteration -  12  :  [ 0.803438 -1.25     -0.10043  -1.263934]
# Current iteration -  13  :  [-1.213211  0.873639 -0.105991 -1.121389]
# Current iteration -  14  :  [-0.764887  0.969779 -0.074177 -0.275902]
# Current iteration -  15  :  [-0.911329  0.80019  -0.072924 -0.093284]
# Current iteration -  16  :  [ 1.22927  -0.93375  -0.114783 -1.187998]
# Current iteration -  17  :  [ 0.63249  -1.245875 -0.0788   -1.251982]
# Current iteration -  18  :  [ 1.002315 -0.748035 -0.074977 -0.395748]
# Current iteration -  19  :  [-0.306009  1.217638 -0.037261 -0.725619]
# Current iteration -  20  :  [-0.499436  1.195734 -0.059719 -1.039128]
# Current iteration -  21  :  [ 0.625022 -0.48252  -0.030159  0.595431]
# Current iteration -  22  :  [-0.950775  1.047069 -0.099553 -0.595302]
# Current iteration -  23  :  [0.077891 0.685654 0.005341 0.786173]
# Current iteration -  24  :  [ 0.82734  -0.896196 -0.074146 -0.071838]
# Current iteration -  25  :  [ 0.796882 -0.962149 -0.076672 -0.246481]
# Current iteration -  26  :  [0.558961 0.525763 0.029388 0.836864]
# Current iteration -  27  :  [ 0.910308 -0.194009 -0.017661  0.090634]
# Current iteration -  28  :  [ 0.011343 -1.112511 -0.001262  0.200594]
# Current iteration -  29  :  [-1.111844  0.989303 -0.109995 -0.825653]
# Current iteration -  30  :  [ 1.076678  0.590797  0.06361  -0.748696]
# Current iteration -  31  :  [-0.162278 -1.235702  0.020053 -0.342311]
# Current iteration -  32  :  [-0.965524 -0.530081  0.051181 -0.453169]
# Current iteration -  33  :  [-0.832412  0.869269 -0.072359 -0.015715]
# Current iteration -  34  :  [-0.764836 -0.254056  0.019431  0.043148]
# Current iteration -  35  :  [-0.50656  -0.110864  0.005616  0.67112 ]
# Current iteration -  36  :  [-0.741666 -0.267176  0.019816  0.041036]
# Current iteration -  37  :  [ 0.34885  -0.259523 -0.009053  0.974569]
# Current iteration -  38  :  [-1.012054  0.839308 -0.084943 -0.412827]
# Current iteration -  39  :  [-1.236702  0.593858 -0.073443 -1.21128 ]
# Current iteration -  40  :  [-0.034114  0.569514 -0.001943  1.061055]
# Current iteration -  41  :  [0.10769  0.676431 0.007285 0.655686]
# Current iteration -  42  :  [ 0.985319 -1.084469 -0.106855 -0.741483]
# Current iteration -  43  :  [-0.520214 -1.239242  0.064467 -1.166114]
# Current iteration -  44  :  [ 0.510555 -0.19071  -0.009737  0.355639]
# Current iteration -  45  :  [ 0.12283  -1.083744 -0.013312  0.073505]
# Current iteration -  46  :  [-0.976586  0.710821 -0.069418 -0.32877 ]
# Current iteration -  47  :  [-0.810253  0.025446 -0.002062  0.767823]
# Current iteration -  48  :  [-0.86258  -0.558433  0.048169 -0.101667]
# Current iteration -  49  :  [7.572293e-03 2.159694e-01 1.635383e-04 1.374617e+00]
# Current iteration -  50  :  [ 1.117218 -0.648085 -0.072405 -0.853044]
# Current iteration -  51  :  [-2.008104e-01 -3.209822e-02  6.445656e-04  1.081469e+00]
# Current iteration -  52  :  [-0.984147  1.230909 -0.12114  -1.215218]
# Current iteration -  53  :  [ 1.054484 -0.894845 -0.09436  -0.569939]
# Current iteration -  54  :  [-0.823072  0.876088 -0.072108 -0.019805]
# Current iteration -  55  :  [-1.181953  0.096019 -0.011349 -0.062022]
# Current iteration -  56  :  [-1.197988  1.124893 -0.134761 -1.27564 ]
# Current iteration -  57  :  [-0.427303 -0.5722    0.02445   0.659387]
# Current iteration -  58  :  [ 0.849207 -0.860865 -0.073105 -0.022954]
# Current iteration -  59  :  [ 0.841078 -0.859173 -0.072263 -0.007328]
# Current iteration -  60  :  [0.285816 0.526656 0.015053 0.390792]
# Current iteration -  61  :  [ 0.970656  0.497454  0.048286 -0.483299]
# Current iteration -  62  :  [-0.695739 -1.04997   0.073051 -0.598762]
# Current iteration -  63  :  [-0.857032  0.845343 -0.072449 -0.009832]
# Current iteration -  64  :  [-0.172214  1.066672 -0.01837  -0.049694]
# Current iteration -  65  :  [-0.594447  0.139012 -0.008264  0.524562]
# Current iteration -  66  :  [ 0.222643 -1.169361 -0.026035 -0.390567]
# Current iteration -  67  :  [ 0.974776 -0.207708 -0.020247 -0.036271]
# Current iteration -  68  :  [ 0.825169 -0.857938 -0.070794  0.017236]
# Current iteration -  69  :  [ 0.771794  1.016681  0.078467 -0.435227]
# Current iteration -  70  :  [-1.217254 -0.938873  0.114285 -1.145605]
# Current iteration -  71  :  [ 1.009813  0.409976  0.0414   -0.547296]
# Current iteration -  72  :  [0.100669 0.75878  0.007639 0.621057]
# Current iteration -  73  :  [0.855992 0.235808 0.020185 0.004568]
# Current iteration -  74  :  [ 0.914304  0.862744  0.078881 -0.153117]
# Current iteration -  75  :  [-0.229878  0.439797 -0.01011   0.473724]
# Current iteration -  76  :  [-0.416417  0.854978 -0.035603 -0.227066]
# Current iteration -  77  :  [0.02824  0.568452 0.001605 1.078955]
# Current iteration -  78  :  [ 1.046765  0.84615   0.088572 -0.528471]
# Current iteration -  79  :  [-0.104784 -0.841828  0.008821  0.511614]
# Current iteration -  80  :  [ 0.716858 -0.276902 -0.01985   0.055374]
# Current iteration -  81  :  [-0.442798 -1.168726  0.051751 -0.912455]
# Current iteration -  82  :  [ 1.244812 -0.760748 -0.094699 -1.251534]
# Current iteration -  83  :  [ 0.88279   0.339194  0.029944 -0.247528]
# Current iteration -  84  :  [ 0.196452 -0.857133 -0.016839  0.137006]
# Current iteration -  85  :  [-0.979453  1.205205 -0.118044 -1.121592]
# Current iteration -  86  :  [-0.991131 -1.231088  0.122017 -1.220093]
# Current iteration -  87  :  [ 1.037394 -0.953514 -0.098917 -0.572224]
# Current iteration -  88  :  [-0.846873 -0.062669  0.005307  0.638632]
# Current iteration -  89  :  [-0.278522 -0.713568  0.019874  0.057573]
# Current iteration -  90  :  [-1.237161 -0.714594  0.088407 -1.230731]
# Current iteration -  91  :  [-0.740967 -0.695753  0.051553  0.391814]
# Current iteration -  92  :  [-5.299484e-01  1.703063e-02 -9.025357e-04  1.143143e+00]
# Current iteration -  93  :  [ 1.032781 -1.240947 -0.128163 -1.286422]
# Current iteration -  94  :  [-0.691985  1.094602 -0.075745 -0.755798]
# Current iteration -  95  :  [-1.201221 -1.247759  0.149883 -1.565364]
# Current iteration -  96  :  [-0.229209  0.101119 -0.002318  0.582549]
# Current iteration -  97  :  [-0.775333  1.22806  -0.095216 -1.189861]
# Current iteration -  98  :  [-1.077635 -1.013206  0.109187 -0.762348]
# Current iteration -  99  :  [ 0.08207  -0.408059 -0.003349  0.819967]

# %% [markdown]
# Summary of the improvement of the best found point:

# %%
X_val = X_step[np.all(C_step>=0,axis=1)]
Y_val = Y_step[np.all(C_step>=0,axis=1)]
C_val = C_step[np.all(C_step>=0,axis=1)]

A_val = np.hstack((X_val,Y_val,C_val))

T =  0.00
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = -0.01
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = -0.03
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = -0.05
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = -0.07
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
print(np.argmin(Y_val,axis=0)[0],X_val[np.argmin(Y_val,axis=0)][0],Y_val[np.argmin(Y_val,axis=0)][0])
# Out:
# 0 [-0.1875  0.0625] [-0.001172]
# 2 [ 0.5625 -0.3125] [-0.017578]
# 12 [ 0.622961 -0.810898] [-0.050516]
# 12 [ 0.622961 -0.810898] [-0.050516]
# 14 [ 0.850728 -0.839911] [-0.071454]
# 14 [ 0.850728 -0.839911] [-0.071454]

# %% [markdown]
# Summary of the optimization:

# %%
print("Point step where minimium was found: ",np.argmin(Y_step))
print("Exact Global minima: ")
print(np.array([-0.84852813,+0.84852813,-0.072]))
print(np.array([+0.84852813,-0.84852813,-0.072]))
print("Global minima found: ")
print(np.hstack((X_val[Y_val[:,0]<-0.07,:],Y_val[Y_val<-0.07][:,np.newaxis])))
# Out:
# Point step where minimium was found:  9
# Exact Global minima:
# [-0.848528  0.848528 -0.072   ]
# [ 0.848528 -0.848528 -0.072   ]
# Global minima found:
# [[ 0.850728 -0.839911 -0.071454]
#  [ 0.825169 -0.857938 -0.070794]]

# %% [markdown]
# Plotting the heatmap of the Simionescu function against the scatterplot of the queried points, one obtains the picture below:

# %%
fig = plt.figure(figsize = (12,12))
ax.set_aspect('equal')

plt.imshow(zv.T,cmap=cm.coolwarm,extent=(-1.25,1.25,-1.25,1.25),origin='bottom')
plt.scatter(X_step[:,0],X_step[:,1],marker='x',color='black')

plt.xlim(-1.25,1.25)
plt.ylim(-1.25,1.25)

plt.show()

# %% [markdown]
# Creating a series of .jpg files so one can create a gif with the dynamic visualization of the Bayesian Optimization loop:

# %%
import os

if(not os.path.exists("gif")):
    os.mkdir("gif")

fig = plt.figure(figsize = (12,12))
plt.xlim((-1.25,1.25))
plt.ylim((-1.25,1.25))
for n in range(iter_count):
    fig.clf()
    plt.xlim((-1.25,1.25))
    plt.ylim((-1.25,1.25))
    plt.imshow(zv.T,cmap=cm.coolwarm,aspect ='equal',origin='lower',extent=(-1.25,1.25,-1.25,1.25))
    plt.scatter(X_step[0:(n+num_init),0],X_step[0:(n+num_init),1],c='black',marker='x')
    plt.savefig("gif/BO_Simionescu-MC1-"+str(n)+"-("+typ_init+","+str(num_init)+").jpg", bbox_inches='tight')
