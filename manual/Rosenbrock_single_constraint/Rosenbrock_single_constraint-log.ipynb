# %% [markdown]
# # Rosenbrock function - One constraint
#
# ### Written by José Hugo Elsas, Tecgraf (PUC-Rio), BR.
#
# *Last updated Monday, 6 May 2019.*

# %% [markdown]
# This is a GPyOpt constrained optimization example for the [Rosenbrock function with a disk constraint](https://en.wikipedia.org/wiki/Test_functions_for_optimization). The global minimum is:
#
# $f(1.0,1.0) = 0.0$
#
# The important imports are the [GPy](https://sheffieldml.github.io/GPy/) and [GPyOpt](https://github.com/SheffieldML/GPyOpt) libraries, and the initial_design function to select the first points to initialize the method. This function requires dealing with constraint, which is done using the acquisition function of [Expected Improvement](https://www.researchgate.net/publication/248818761_The_application_of_Bayesian_methods_for_seeking_the_extremum) (EI) with [Probability of Feasibility](https://dl.acm.org/citation.cfm?id=3044997) (PoF). For references of Probability of Feasibility, read [Gardner et. al. (2014)](https://stat.columbia.edu/~cunningham/pdf/GardnerICML2014.pdf), [Gelbart (2015)](https://dash.harvard.edu/bitstream/handle/1/17467236/GELBART-DISSERTATION-2015.pdf?sequence=4&isAllowed=y) and [Schonlau (2015)](https://www.collectionscanada.gc.ca/obj/s4/f2/dsk3/ftp04/nq22234.pdf). A modified version of the Bayesian Optimization method is required, named ModularConstrainedBayesianOptimization.

# %%
# %pylab inline
import GPy
import GPyOpt
import numpy as np
import matplotlib.pyplot as plt
from GPyOpt.experiment_design import initial_design
from GPyOpt.acquisitions.EI import AcquisitionEI
from GPyOpt.methods import ModularBayesianOptimization
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The definition of the Rosenbrock function with a logarithm shrinking and with the disk constraint, is given by the functions below:

# %%
def rosenbrock(x,y):
    return np.log(1.+((1.0-x)**2+100*((y-x**2)**2)))

def disk_contraint(x,y):
    return (2.-(x**2)-(y**2))

# %% [markdown]
# Create (xv,yv) variables to be able to plot and visualize the function in 2D and 3D

# %%
X_ax = np.linspace(-1.5,1.5,201)
Y_ax = np.linspace(-1.5,1.5,201)

v_rosenbrock = np.vectorize(rosenbrock)

xv, yv = np.meshgrid(X_ax, Y_ax, sparse=False, indexing='ij')

zv = np.zeros(xv.shape)

for i in range(X_ax.shape[0]):
    for j in range(Y_ax.shape[0]):
        g = disk_contraint(X_ax[i],Y_ax[j])
        if(g>=0):
            zv[i,j] = rosenbrock(X_ax[i],Y_ax[j])
        else:
            zv[i,j] = np.nan

# %% [markdown]
# To the left, the 2D heatmap plot of the Rosenbrock function, and to the right, a 3D rendering of the same function. There is one global minimum, which correspond to the tip of the beak at $(1.0,1.0)$.

# %%
fig = plt.figure(figsize=(16,6))

ax = fig.add_subplot(1,2,1)
ax.set_aspect('equal')
ax.grid()
ax.imshow(zv.T,cmap=cm.coolwarm,extent=(-1.5,1.5,-0.5,2.5),origin='bottom')

ax2 = fig.add_subplot(1,2,2, projection='3d')
ax2.plot_surface(xv, yv, zv, rstride=1, cstride=1,
                cmap=cm.coolwarm, edgecolor='none',
                vmin = 0, vmax = 6)

ax2.set_title('Rosenbrock function with one constraint');
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('z')
plt.show()

# %% [markdown]
# The search space of the optimization problem is the box $[-1.5,1.5] \times [-1.5,1.5]$, with continuous variables.
#
# There are two GP models: One for interpolating the objective function, and another for interpolating the constraint. In this case the constraint is very simple,but it might not be the case in other problems.
#
# The acquisition function is the Expected Improvement with Probability of Feasibility extension, named AcquisitionEI_PoF. The evaluator is the standard serial evaluator. jitter is set to $10^{-8}$
#
# The initial choice of points is done via the initial_design function, according to a [Latin Hypercube](https://en.wikipedia.org/wiki/Latin_hypercube_sampling) sampling. The objective function and the constraints are evaluated on those points before the Bayesian optimization loop.

# %%
np.set_printoptions(precision=6)

objective = None 
constraint = None

space =[{'name': 'var_1', 'type': 'continuous', 'domain': (-1.5,1.5)},
        {'name': 'var_2', 'type': 'continuous', 'domain': (-1.5,1.5)}]
space = GPyOpt.Design_space(space = space)

kernel   = None 
kernel_c = None

model    = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False)
model_c1 = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False)
model_c  = [model_c1]

aquisition_optimizer = GPyOpt.optimization.AcquisitionOptimizer(space)

acquisition = AcquisitionEI(model,space,optimizer=aquisition_optimizer,jitter=1e-8,model_c=model_c,jitter_c=[0.0])

# --- CHOOSE a collection method
evaluator = GPyOpt.core.evaluators.Sequential(acquisition)

num_init = 20
typ_init = 'latin'
X_init = initial_design(typ_init,space,num_init)

Y_init = np.zeros((X_init.shape[0],1))
C_init = np.zeros((X_init.shape[0],1))

for i in range(num_init):
    Y_init[i,0] = rosenbrock(X_init[i,0],X_init[i,1])
    C_init[i,0] = disk_contraint(X_init[i,0],X_init[i,1])
    
print(np.hstack((X_init,Y_init,C_init)))
# Out:
# [[ 0.075     0.675     3.842928  1.53875 ]
#  [ 0.975    -0.825     5.756644  0.36875 ]
#  [ 1.125    -1.275     6.471563 -0.89125 ]
#  [-0.975    -0.975     5.928801  0.09875 ]
#  [-1.125     0.375     4.440731  0.59375 ]
#  [-0.825    -1.425     6.104115 -0.71125 ]
#  [-0.225    -0.525     3.573329  1.67375 ]
#  [-1.275     1.425     2.322453 -1.65625 ]
#  [-1.425     0.225     5.807869 -0.08125 ]
#  [ 1.275     0.975     3.770619 -0.57625 ]
#  [ 0.225     0.075     0.506841  1.94375 ]
#  [-0.375    -0.375     3.383629  1.71875 ]
#  [ 0.825    -0.675     5.219288  0.86375 ]
#  [-0.675     0.825     2.859306  0.86375 ]
#  [ 1.425    -1.125     6.904728 -1.29625 ]
#  [-0.075     1.125     4.847769  0.72875 ]
#  [-0.525     1.275     4.636675  0.09875 ]
#  [ 0.375    -0.225     2.691839  1.80875 ]
#  [ 0.675    -0.075     3.376287  1.53875 ]
#  [ 0.525     0.525     2.007464  1.44875 ]]

# %% [markdown]
# The main external loop is executed using the ModularConstrainedBayesianOptimization object, initialized with the interpolation method of usual Gaussian Process, the acquisition function is the Expected Improvement w/ PoF, and default jitter used for a standard Bayesian Optimization loop.

# %%
iter_count = 120-num_init
current_iter = 0
X_step = X_init
Y_step = Y_init
C_step = C_init 

while current_iter < iter_count:
    bo_step = ModularBayesianOptimization(model, space, objective, acquisition, evaluator, 
                                          X_init = X_step, Y_init = Y_step, C_init = C_step, 
                                          model_c = model_c, normalize_Y = False)
    
    x_next = bo_step.suggest_next_locations()
    y_next = np.array(rosenbrock(x_next[0][0],x_next[0][1]))
    c_next = np.array(disk_contraint(x_next[0][0],x_next[0][1]))
    print("Current iteration - ",current_iter," : ",np.hstack([x_next[0],y_next,c_next]))
    
    X_step = np.vstack((X_step, x_next))
    Y_step = np.vstack((Y_step, y_next))
    C_step = np.vstack((C_step, c_next))
    
    current_iter += 1
# Out:
# Current iteration -  0  :  [0.130825 0.121444 1.04518  1.968136]
# Current iteration -  1  :  [0.102423 0.118373 1.088396 1.975497]
# Current iteration -  2  :  [0.102553 0.114026 1.056688 1.976481]
# Current iteration -  3  :  [0.124467 0.108381 0.966754 1.972762]
# Current iteration -  4  :  [0.224864 0.005961 0.587664 1.949401]
# Current iteration -  5  :  [0.313593 0.104355 0.388504 1.890769]
# Current iteration -  6  :  [ 0.149819 -1.396316  5.313261  0.027857]
# Current iteration -  7  :  [0.334181 0.12105  0.373011 1.87367 ]
# Current iteration -  8  :  [1.385629 0.242946 5.643286 0.021009]
# Current iteration -  9  :  [0.623688 1.260063 4.344052 0.023254]
# Current iteration -  10  :  [0.335168 0.117283 0.367726 1.873907]
# Current iteration -  11  :  [-0.477663  0.236173  1.159991  1.71606 ]
# Current iteration -  12  :  [0.449552 0.175981 0.315685 1.766934]
# Current iteration -  13  :  [-0.252824  0.029772  0.988117  1.935194]
# Current iteration -  14  :  [0.609204 0.27615  0.720192 1.552612]
# Current iteration -  15  :  [-1.048101  0.945321  2.020429  0.007853]
# Current iteration -  16  :  [-1.336483 -0.450395  6.227898  0.010957]
# Current iteration -  17  :  [0.463114 0.216637 0.253645 1.738594]
# Current iteration -  18  :  [0.476868 0.25009  0.281515 1.710052]
# Current iteration -  19  :  [0.440267 0.219535 0.321614 1.757969]
# Current iteration -  20  :  [0.473126 0.221713 0.245337 1.726995]
# Current iteration -  21  :  [-0.03819  -0.114685  1.231616  1.985389]
# Current iteration -  22  :  [0.49375  0.223185 0.261394 1.7064  ]
# Current iteration -  23  :  [-0.610166  0.042445  2.672306  1.625895]
# Current iteration -  24  :  [0.485657 0.22472  0.244486 1.713639]
# Current iteration -  25  :  [-0.353058  0.435288  2.524156  1.685874]
# Current iteration -  26  :  [0.487396 0.224966 0.245775 1.711835]
# Current iteration -  27  :  [-1.229290e+00  6.961747e-01  4.282052e+00  4.186782e-03]
# Current iteration -  28  :  [-0.701121  0.431946  1.446758  1.321853]
# Current iteration -  29  :  [ 0.306271 -0.882014  4.571643  1.12825 ]
# Current iteration -  30  :  [ 1.359187e+00 -3.828228e-01  6.211631e+00  6.057522e-03]
# Current iteration -  31  :  [0.227265 1.390968 5.198356 0.01356 ]
# Current iteration -  32  :  [0.486948 0.224881 0.245451 1.71231 ]
# Current iteration -  33  :  [0.924723 0.688401 1.331041 0.670991]
# Current iteration -  34  :  [0.865855 0.475411 2.144958 1.02428 ]
# Current iteration -  35  :  [0.805584 0.871592 1.790772 0.591362]
# Current iteration -  36  :  [-0.325322 -1.06791   4.94538   0.753733]
# Current iteration -  37  :  [0.484326 0.224552 0.243698 1.715004]
# Current iteration -  38  :  [ 6.062778e-01 -1.276284e+00  5.603525e+00  3.527456e-03]
# Current iteration -  39  :  [-8.885321e-01  1.099710e+00  2.652557e+00  1.147738e-03]
# Current iteration -  40  :  [-0.879339  0.65915   1.763621  0.792284]
# Current iteration -  41  :  [0.986827 1.011596 0.133496 0.002844]
# Current iteration -  42  :  [0.906889 1.073906 1.992225 0.024278]
# Current iteration -  43  :  [1.017423 0.92761  0.768612 0.104392]
# Current iteration -  44  :  [0.748573 0.638035 0.510751 1.03255 ]
# Current iteration -  45  :  [-0.232699  0.188157  1.462183  1.910448]
# Current iteration -  46  :  [-0.77354  -0.512886  4.84916   1.138584]
# Current iteration -  47  :  [ 0.132913 -0.477757  3.269427  1.754082]
# Current iteration -  48  :  [0.672311 0.465686 0.118765 1.331135]
# Current iteration -  49  :  [0.696924 0.513049 0.154128 1.251078]
# Current iteration -  50  :  [0.623561 0.405853 0.157595 1.446455]
# Current iteration -  51  :  [-0.272984  0.799816  4.01143   1.285775]
# Current iteration -  52  :  [-1.009846 -0.049291  4.781914  0.977782]
# Current iteration -  53  :  [-0.198727 -1.385156  5.324956  0.04185 ]
# Current iteration -  54  :  [0.32128  0.979704 4.36033  0.93696 ]
# Current iteration -  55  :  [-0.773443  0.261962  2.737718  1.333162]
# Current iteration -  56  :  [0.657248 0.469118 0.227486 1.347953]
# Current iteration -  57  :  [0.69548  0.449574 0.189906 1.31419 ]
# Current iteration -  58  :  [0.579676 0.348307 0.175431 1.542658]
# Current iteration -  59  :  [-0.036735 -0.843132  4.295784  1.287779]
# Current iteration -  60  :  [-0.59705   0.579922  2.145198  1.307222]
# Current iteration -  61  :  [0.691739 0.479053 0.090805 1.292006]
# Current iteration -  62  :  [-0.394574  0.075244  1.278704  1.838649]
# Current iteration -  63  :  [-0.515607 -0.761101  4.689142  1.154876]
# Current iteration -  64  :  [-0.243544 -0.149115  1.930168  1.918451]
# Current iteration -  65  :  [ 0.943452 -0.279656  4.926068  1.031691]
# Current iteration -  66  :  [0.762966 0.560084 0.099602 1.104188]
# Current iteration -  67  :  [ 0.48306  -0.530855  4.088792  1.484845]
# Current iteration -  68  :  [0.796007 0.595646 0.170478 1.011578]
# Current iteration -  69  :  [-2.216525e-01  1.395668e+00  5.213897e+00  2.981028e-03]
# Current iteration -  70  :  [-0.091049  0.030429  0.806208  1.990784]
# Current iteration -  71  :  [ 0.134053 -0.164946  1.628399  1.954822]
# Current iteration -  72  :  [-0.560229  0.369767  1.32093   1.549416]
# Current iteration -  73  :  [0.733897 0.526956 0.081009 1.183712]
# Current iteration -  74  :  [-0.897683  0.857402  1.582502  0.459027]
# Current iteration -  75  :  [-1.408505e+00 -1.143595e-01  6.102703e+00  3.035020e-03]
# Current iteration -  76  :  [ 1.411287e+00 -6.839720e-02  6.053459e+00  3.589838e-03]
# Current iteration -  77  :  [-0.643236 -0.226915  3.800996  1.534757]
# Current iteration -  78  :  [-1.188127e+00 -7.652095e-01  6.173073e+00  2.808115e-03]
# Current iteration -  79  :  [-0.053398  0.404985  2.905849  1.833136]
# Current iteration -  80  :  [0.977714 0.982702 0.069709 0.078373]
# Current iteration -  81  :  [0.962558 0.968396 0.16278  0.135692]
# Current iteration -  82  :  [ 0.0732   -0.026811  0.674189  1.993923]
# Current iteration -  83  :  [0.990594 0.989352 0.00659  0.039906]
# Current iteration -  84  :  [ 0.638919 -0.931988  5.197091  0.72318 ]
# Current iteration -  85  :  [ 0.65812  -0.327066  4.075935  1.459905]
# Current iteration -  86  :  [-0.620583 -1.13788   5.462051  0.320106]
# Current iteration -  87  :  [1.008376e+00 9.912612e-01 6.335218e-02 5.799050e-04]
# Current iteration -  88  :  [0.726182 0.508174 0.105903 1.214418]
# Current iteration -  89  :  [0.743993 0.544638 0.070866 1.149844]
# Current iteration -  90  :  [0.403361 0.033243 1.109187 1.836195]
# Current iteration -  91  :  [0.743777 0.544129 0.071284 1.15072 ]
# Current iteration -  92  :  [0.280673 0.320763 1.997846 1.818333]
# Current iteration -  93  :  [9.951597e-01 9.917035e-01 2.085208e-04 2.618129e-02]
# Current iteration -  94  :  [ 0.108441 -1.124028  4.87364   0.724802]
# Current iteration -  95  :  [0.743897 0.544436 0.071011 1.150208]
# Current iteration -  96  :  [0.539171 0.366826 0.583219 1.574734]
# Current iteration -  97  :  [1.254618 0.608931 4.545561 0.055138]
# Current iteration -  98  :  [0.626974 0.370303 0.174878 1.46978 ]
# Current iteration -  99  :  [-0.432424  1.012239  4.264866  0.788381]

# %% [markdown]
# Summary of the improvement of the best found point.

# %%
X_val = X_step[np.all(C_step>=0,axis=1)]
Y_val = Y_step[np.all(C_step>=0,axis=1)]
C_val = C_step[np.all(C_step>=0,axis=1)]

A_val = np.hstack((X_val,Y_val,C_val))

T = 5.0
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = 3.0
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = 1.0
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = 0.1
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
T = 0.01
print(np.argwhere(A_val[:,2]<T)[0,0],X_val[np.argwhere(A_val[:,2]<T)[0,0]],Y_val[np.argwhere(A_val[:,2]<T)[0,0]])
print(np.argmin(Y_val,axis=0)[0],X_val[np.argmin(Y_val,axis=0)][0],Y_val[np.argmin(Y_val,axis=0)][0])
# Out:
# 0 [0.075 0.675] [3.842928]
# 5 [0.225 0.075] [0.506841]
# 5 [0.225 0.075] [0.506841]
# 75 [0.691739 0.479053] [0.090805]
# 97 [0.990594 0.989352] [0.00659]
# 107 [0.99516  0.991703] [0.000209]

# %% [markdown]
# Summary of the optimization:

# %%
print("Point step where minimium was found: ",np.argmin(Y_step))
print("Exact Global minima: ")
print(np.array([1.0,1.0,0.0]))
print("Global minima found: ")
print(np.hstack((X_step[Y_step[:,0]<0.05,:],Y_step[Y_step<0.05][:,np.newaxis])))
# Out:
# Point step where minimium was found:  113
# Exact Global minima:
# [1. 1. 0.]
# Global minima found:
# [[9.905935e-01 9.893525e-01 6.590370e-03]
#  [9.951597e-01 9.917035e-01 2.085208e-04]]

# %% [markdown]
# Plotting the heatmap of the Rosenbrock function against the scatterplot of the queried points, one obtains the picture below:

# %%
fig = plt.figure(figsize = (12,12))
ax.set_aspect('equal')

plt.imshow(zv.T,cmap=cm.coolwarm,extent=(-1.5,1.5,-1.5,1.5),origin='bottom')
plt.scatter(X_step[:,0],X_step[:,1],marker='x',color='black')

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.show()

# %% [markdown]
# Creating a series of .jpg files so one can create a gif with the dynamic visualization of the Bayesian Optimization loop:

# %%
import os

if(not os.path.exists("gif")):
    os.mkdir("gif-log")

fig = plt.figure(figsize = (12,12))
plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))
for n in range(iter_count):
    fig.clf()
    plt.xlim((-1.5,1.5))
    plt.ylim((-1.5,1.5))
    plt.imshow(zv.T,cmap=cm.coolwarm,aspect ='equal',origin='lower',extent=(-1.5,1.5,-1.5,1.5))
    plt.scatter(X_step[0:(n+num_init),0],X_step[0:(n+num_init),1],c='black',marker='x')
    plt.savefig("gif-log/BO_Rosenbrock-MC1-"+str(n)+"-("+typ_init+","+str(num_init)+",log).png", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-10-22a069761d76> in <module>
#       2
#       3 if(not os.path.exists("gif")):
# ----> 4     os.mkdir("gif-log")
#       5
#       6 fig = plt.figure(figsize = (12,12))
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'gif-log'
