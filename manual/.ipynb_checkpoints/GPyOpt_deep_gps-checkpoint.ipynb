# %%
# %pylab inline  
import GPy
import GPyOpt
from numpy.random import seed
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# create the object function
f_true = GPyOpt.objective_examples.experiments2d.sixhumpcamel()
f_sim = GPyOpt.objective_examples.experiments2d.sixhumpcamel(sd = 0.1)
bounds =[{'name': 'var_1', 'type': 'continuous', 'domain': f_true.bounds[0]},
         {'name': 'var_2', 'type': 'continuous', 'domain': f_true.bounds[1]}]
f_true.plot()

# %%
# Creates three identical objects that we will later use to compare the optimization strategies 
myBopt2D = GPyOpt.methods.BayesianOptimization(f_sim.f,
                                              domain=bounds,
                                              model_type = 'deepGP',
                                              acquisition_type='EI',  
                                              normalize_Y = True,
                                              acquisition_weight = 0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-72da3466d315> in <module>()
#       5                                               acquisition_type='EI',
#       6                                               normalize_Y = True,
# ----> 7                                               acquisition_weight = 0.1)
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/methods/bayesian_optimization.pyc in __init__(self, f, domain, constrains, cost_withGradients, model_type, X, Y, initial_design_numdata, initial_design_type, acquisition_type, normalize_Y, exact_feval, acquisition_optimizer_type, model_update_interval, verbosity, evaluator_type, batch_size, num_cores, **kwargs)
#      97
#      98         # --- Initilize everyting
# ---> 99         self.run_optimization(0)
#     100
#     101     def _model_chooser(self):
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in run_optimization(self, max_iter, max_time, eps, verbosity, report_file, **kargs)
#      65             # --- Update model
#      66             try:
# ---> 67                 self._update_model()
#      68             except np.linalg.linalg.LinAlgError:
#      69                 break
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _update_model(self)
#     135         if (self.num_acquisitions%self.model_update_interval)==0:
#     136             if self.normalize_Y:
# --> 137                 self.model.updateModel(self.X,(self.Y-self.Y.mean())/(self.Y.std()),None,None)
#     138             else:
#     139                 self.model.updateModel(self.X, self.Y,None,None)
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/models/deepgpmodel.py in updateModel(self, X_all, Y_all, X_new, Y_new)
#      71                 Y_all = (Y_all - Y_all.mean())/(Y_all.std())
#      72
# ---> 73                 self._create_model(X_all, Y_all)
#      74
#      75                 # Optimization
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/models/deepgpmodel.py in _create_model(self, X, Y)
#      47
#      48         # --- kernel and dimension of the hidden layer
# ---> 49         if kernel == None:
#      50                 kern = [GPy.kern.Matern32(self.Ds, ARD=False), GPy.kern.Matern32(self.X.shape[1], ARD=False)]
#      51         else:
#
# NameError: global name 'kernel' is not defined

# %%
# runs the optimization for the three methods
max_iter = 2  # maximum time 40 iterations

myBopt2D.run_optimization(max_iter)
# Out:
#    ** Maximum number of iterations reached **

# %%
myBopt2D.plot_acquisition()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-cbc56553a468> in <module>()
# ----> 1 myBopt2D.plot_acquisition()
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in plot_acquisition(self, filename)
#     148         """
#     149         return plot_acquisition(self.acquisition.space.get_bounds(),
# --> 150                                 self.model.model.X.shape[1],
#     151                                 self.model.model,
#     152                                 self.model.model.X,
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'X'

# %%
myBopt2D.model.model.predict(myBopt2D.X)
# Out:
# array([-1.03351325,  0.36509077, -0.24945301,  1.10903013,  0.507947  ,
#        -0.97232175, -0.81387875])

# %%
myBopt2D.Y
# Out:
# array([[-0.9517939 ],
#        [ 0.42853294],
#        [-0.39391165],
#        [ 0.6729146 ],
#        [ 0.27681623],
#        [-0.84914355],
#        [-0.88084084]])
