# %% [markdown]
# ## General GPyOPt new way of use

# %%
# %pylab inline
import GPyOpt
import GPy
from numpy.random import seed
seed(1234)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem definition

func      = GPyOpt.objective_examples.experiments2d.sixhumpcamel()

space =[{'name': 'var_1', 'type': 'continuous', 'domain': func.bounds[0]},
        {'name': 'var_2', 'type': 'continuous', 'domain': func.bounds[0]}]

constrains = [
    {'name': 'constr_1', 'constrain': '-x[:,1] -.5 + abs(x[:,0]) - np.sqrt(1-x[:,0]**2)'},
    {'name': 'constr_2', 'constrain': 'x[:,1] +.5 - abs(x[:,0]) - np.sqrt(1-x[:,0]**2)'}]
# Out:
# [(-2, 2), (-1, 1)]

# %%
bo = GPyOpt.methods.BayesianOptimization(func.f, model_type='GP',acquisition_type ='EI',exact_feval = True, bounds= func.bounds)

# %%
# --- Stop conditions
max_time  = None 
max_iter  = 20
tolerance = 1e-8     # distance between two consecutive observations  

# Run the optimization                                                  
bo.run_optimization(max_iter = max_iter, max_time = max_time, eps = tolerance)
# Out:
# *Optimization completed:

# %%
bo.plot_acquisition()

# %%
func.plot()

# %%
bo.model.model.optimize_restarts(2,verbose=False)
# Out:
# [<paramz.optimization.optimization.opt_lbfgsb at 0x10ae0dbd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10ae0d490>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x108ec6750>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10ae26110>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x1039efcd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10ae13a90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c612690>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a38ef50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a128850>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x1098d8cd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c612a50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x1098d8d10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10ae135d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10ae13610>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x108fb6d50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x1098d89d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c612d50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c612c50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x103a0f090>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x1098d8b90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x1098d8d90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c612550>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b567a90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x103a0f150>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a128290>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x103a0f390>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b567550>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b5671d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b5677d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b567050>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746310>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746550>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746450>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b567e10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a7467d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746e90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746590>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746bd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746b50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746b10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746c50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c5292d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c529c50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c529bd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746490>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746e10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746850>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c5290d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746410>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746c90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746090>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a7462d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a7461d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c529a50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a7460d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10cef35d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10a746110>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10cef3450>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x108c5e4d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10cef3ad0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x108269cd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b567ad0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10ae0d1d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b567cd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10c58d810>]
