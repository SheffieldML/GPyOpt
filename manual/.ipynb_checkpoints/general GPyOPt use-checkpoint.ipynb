# %% [markdown]
# ## General GPyOPt new way of use

# %%
# %pylab inline
import GPyOpt
import GPy
from numpy.random import seed
seed(1234)

# %%
# Problem definition
func      = GPyOpt.objective_examples.experiments2d.sixhumpcamel()

domain =[{'name': 'var_1', 'type': 'continuous', 'domain':(-2,2) },
         {'name': 'var_2', 'type': 'continuous', 'domain':(-1,1) }]

constrains = [
    {'name': 'constr_1', 'constrain': '-x[:,1] -.5 + abs(x[:,0]) - np.sqrt(1-x[:,0]**2)'},
    {'name': 'constr_2', 'constrain': 'x[:,1] +.5 - abs(x[:,0]) - np.sqrt(1-x[:,0]**2)'}]

# %%
bo = GPyOpt.methods.BayesianOptimization(func.f, domain, model_type='GP',batch_size=4, batch_method_type='predictive', acquisition_type ='EI',exact_feval = True)

# %%
bo.batch_method

# %%
# --- Stop conditions
max_time  = None 
max_iter  = 5
tolerance = 1e-8     # distance between two consecutive observations  

# Run the optimization                                                  
bo.run_optimization(max_iter = max_iter, max_time = max_time, eps = tolerance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-48b38d94d70c> in <module>()
#       5
#       6 # Run the optimization
# ----> 7 bo.run_optimization(max_iter = max_iter, max_time = max_time, eps = tolerance)
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in run_optimization(self, max_iter, max_time, eps, verbosity, report_file, **kargs)
#      74
#      75             # --- Update and optimize acquisition and compute the exploration level in the next evaluation
# ---> 76             self.suggested_sample = self._compute_next_evaluations()
#      77             self._compute_exploration_next_evaluations()
#      78
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _compute_next_evaluations(self)
#     137
#     138     def _compute_next_evaluations(self):
# --> 139         return self.batch_method.compute_batch() # in the sequential case this simpy optimzes the acquisition
#     140
#     141
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/batch_designs/predictive.py in compute_batch(self)
#      23         model_local = self.acquisition.model.copy()  #### how to make acopy of this???
#      24         space_local = self.acquisition.space.space
# ---> 25         objective_local = GPyOpt.core.task.SingleObjective(f = lambda x: 0 )
#      26         acquisition_local = deepcopy(self.acquisition)
#      27
#
# NameError: global name 'GPyOpt' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-48b38d94d70c> in <module>()
#       5
#       6 # Run the optimization
# ----> 7 bo.run_optimization(max_iter = max_iter, max_time = max_time, eps = tolerance)
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in run_optimization(self, max_iter, max_time, eps, verbosity, report_file, **kargs)
#      74
#      75             # --- Update and optimize acquisition and compute the exploration level in the next evaluation
# ---> 76             self.suggested_sample = self._compute_next_evaluations()
#      77             self._compute_exploration_next_evaluations()
#      78
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _compute_next_evaluations(self)
#     137
#     138     def _compute_next_evaluations(self):
# --> 139         return self.batch_method.compute_batch() # in the sequential case this simpy optimzes the acquisition
#     140
#     141
#
# /Users/javiergonzalez/workspace/GitHub/GPyOpt/GPyOpt/core/batch_designs/predictive.py in compute_batch(self)
#      23         model_local = self.acquisition.model.copy()  #### how to make acopy of this???
#      24         space_local = self.acquisition.space.space
# ---> 25         objective_local = GPyOpt.core.task.SingleObjective(f = lambda x: 0 )
#      26         acquisition_local = deepcopy(self.acquisition)
#      27
#
# NameError: global name 'GPyOpt' is not defined

# %%
bo.acquisition.model.model.X
# Out:
# ObsAr([[-1.2339222 , -0.45481479],
#        [ 0.48843508, -0.44707149],
#        [-0.24908904,  0.60374436],
#        [ 1.14143433,  0.91627871],
#        [ 1.11990323,  0.75186527]])
# ObsAr([[-1.2339222 , -0.45481479],
#        [ 0.48843508, -0.44707149],
#        [-0.24908904,  0.60374436],
#        [ 1.14143433,  0.91627871],
#        [ 1.11990323,  0.75186527]])

# %%
bo.plot_convergence()

# %%
func.plot()

# %%
new_model = bo.model.copy()
# Out:
# Optimization restart 1/5, f = 0.465745695714
# Optimization restart 2/5, f = 0.465745697216
# Optimization restart 3/5, f = 0.465745691929
# Optimization restart 4/5, f = 0.465745698805
# Optimization restart 5/5, f = 0.465745700289

# %%
bo.model.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 0.465745691871<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>        value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.rbf.variance       </td><td class=tg-right>60.6323318273</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale    </td><td class=tg-right>2.11382408681</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.bias.variance      </td><td class=tg-right>25.6795770949</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>        1e-06</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>

# %%
new_model.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 29.2277437945<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>        value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.rbf.variance       </td><td class=tg-right>60.6371047972</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale    </td><td class=tg-right> 2.1138502344</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.bias.variance      </td><td class=tg-right>25.6845154542</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>          0.2</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>

# %%
bo.acquisition.model.model.Gaussian_noise.fix(0.2)
# Out:
# array([0])

# %%
aq.model.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 29.2275296634<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>        value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.rbf.variance       </td><td class=tg-right>60.6323318273</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale    </td><td class=tg-right>2.11382408681</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.bias.variance      </td><td class=tg-right>25.6795770949</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>          0.2</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>

# %%
bo.X[0,1]=333

# %%
Z = bo.X.copy()

# %%
from copy import deepcopy

# %%
new_aq = deepcopy(bo.acquisition)

# %%
bo.acquisition.space.space
# Out:
# [{'dimensionality': 1,
#   'domain': (-2, 2),
#   'name': 'var_1',
#   'type': 'continuous'},
#  {'dimensionality': 1,
#   'domain': (-2, -1, -0.7, 0, 0.7, 1, 2),
#   'name': 'var_2',
#   'type': 'discrete'}]

# %%
new_aq.jitter
# Out:
# 0.01
