# %% [markdown]
# # GPyOpt: The tool for Bayesian Optimization
#
# ### Written by Javier Gonzalez (j.h.gonzalez@sheffield.ac.uk), University of Sheffield.
#
# ## Reference Manual index
#
# =====================================================================================================
# 1. **What is GPyOpt?**
#
# 2. **How to install GPyopt?**
#
# 3. **How to use GPyOpt?**
#     1. Gaussian Processes
#     2. Acquisition functions
#     3. Applications of Bayesian Optimization
#
# 4. **The Basics of Bayesian Optimization**
#
# 5. **1D optimization example**
#
# 6. **2D optimization example**
#
# =====================================================================================================

# %% [markdown]
# ## 1. What is GPyOpt?
#
# GPyOpt (http://sheffieldml.github.io/GPy/) is a tool for optimization (minimization) of black-box functions using Gaussian processes. It is based on GPy (http://sheffieldml.github.io/GPy/) and it has been implemented in Python 2.7 (https://www.python.org/download/releases/2.7/) by the group of Machine Learning (at SITraN) of the university of Sheffield (http://ml.dcs.shef.ac.uk/sitran/).
#
# These are the main features of GPyOPt:
#
# * You can perform Bayesian Optimization with **most common acquisition functions**, such as  Expected improvement (EI), Maximum probability of improvement (MPI) or the Upper confidence bound (GP-UCB).
#
#
# * **Any model available in GPy can used in GPyOpt** as a surrogate of the function to optimize. This includes a wide variety of kernel fuctions (and kernel combinations) and models such as Sparse Gaussian process, usefull to speed up computational costs in large scale scenarios. See GPy  https://gpy.readthedocs.org/en/latest/ for details.
#
#
# * GPyOpt allows you to run **parallel Bayesian optimization**. This is helpful when you want to perform simultaneously several evaluations of the function that you want to optimize.
#
#
# * You can use GPyOpt to **design physical experiments**. If you are, or if you work with, a wetlab person you can use GPyOpt to determine optimal strategies for sequential experimental designs.
#
#
# * GPyOpt contains a repository of **test functions for optimization **.
#
# =====================================================================================================

# %% [markdown]
# ## 2. How to install GPyOPt?
#
# The simplest way to install GPyOpt is using pip. Ubuntu users can do:
#
# ```sh
# sudo apt-get install python-pip
# pip install gpyopt
# ```
# =====================================================================================================

# %% [markdown]
# ## 3. How to use GPyOpt?

# %%
# %pylab inline  
import GPy
import GPyOpt
from numpy.random import seed
seed(12345)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# GPyOpt is easy to use as a black-box functions optimizer. To start you only need:
#
# * Your favorite function $f$ to minimize. We use $f(x)=2x^2$ in this toy example, whose global minimum is at x=0.

# %%
def myf(x):
    return (2*x)**2

# %% [markdown]
# * A set of box constrains, the interval [-1,1] in our case.

# %%
bounds = [(-1,1)]

# %% [markdown]
# * A budget, or number of allowed evaluations of $f$.

# %%
max_iter = 15

# %% [markdown]
# With this three pieces of information GPyOpt has enough to find the minimum of $f$ in the selected region. GPyOpt solves the problem in two steps. First, you need to create a GPyOpt object that stores the problem (f and and box-constrains). You can do it as follows.

# %%
myProblem = GPyOpt.methods.BayesianOptimization(myf,bounds)
# Out:
# WARNING: reconstraining parameters GP_regression.Gaussian_noise

# %% [markdown]
# Next you need to run the optimization for the given budget of iterations

# %%
myProblem.run_optimization(max_iter)
# Out:
# *Optimization completed:
#    -Maximum number of iterations reached.
#  /home/javier/workspace/GitHub/GPy/GPy/core/parameterization/transformations.py:70: RuntimeWarning:overflow encountered in exp
# 1

# %%
myProblem.x_opt
# Out:
# array([ 0.00063039])

# %%
myProblem.fx_opt
# Out:
# array([  1.58954412e-06])

# %% [markdown]
# and to the predicted value value of $f$ at $x^*$ optimum by

# %%
myProblem.plot_acquisition()

# %% [markdown]
# And that's it! Keep reading to learn how GPyOpt uses Bayesian Optimization to solve this an other optimization problem. You will also learn all the features and options that you can use to solve your problems efficiently.
#
# =====================================================================================================

# %% [markdown]
# ## 4. The Basics of Bayesian Optimization
#
# Bayesian optimization (BO) is an strategy for global optimization of black-box functions [(Snoek et al., 2012)](http://papers.nips.cc/paper/4522-practical-bayesian-optimization-of-machine-learning-algorithms.pdf). Let $f: {\mathcal X} \to R$ be a L-Lipschitz  continuous function defined on a compact subset ${\mathcal X} \subseteq R^d$. We are interested in solvig the global optimization problem of finding
# $$ x_{M} = \arg \min_{x \in {\mathcal X}} f(x). $$
#
# We assume that $f$ is a *black-box* from which only perturbed evaluations of the type $y_i = f(x_i) + \epsilon_i$, with $\epsilon_i \sim\mathcal{N}(0,\psi^2)$, are  available. The goal is to make a series of $x_1,\dots,x_N$ evaluations of $f$ such that the *cumulative regret*
# $$r_N= Nf(x_{M})- \sum_{n=1}^N f(x_n),$$
# is minimised. Essentially, $r_N$ is minimised if we start evaluating $f$ at $x_{M}$ as soon as possible.
#
# There are two crucial bits in any Bayesian Optimization (BO) procedure approach.
#
# 1. Define a **prior probability measure** on $f$: this function will capture the our prior beliefs on $f$. The prior will be updated to a 'posterior' using the available data.
#
# 2. Define an **acquisition function** $acqu(x)$: this is a criteria to decide where to sample next in order to gain the maximum information about the location of the global maximum of $f$.
#
# Everytime a new data point is collected. The model is reestimated and the acquisition function optimized again until convergence. Given a prior over the function $f$ and an acquisition function, a BO procedure will converge to the optimum of $f$ under some conditions [(Bull, 2011)](http://arxiv.org/pdf/1101.3501.pdf).

# %% [markdown]
# ### 4.1 Prior probability meassure on $f$: Gaussian processes

# %% [markdown]
# A Gaussian process (GP) is a probability distribution across classes functions, typically smooth, such that each linear finite-dimensional restriction is multivariate Gaussian [(Rasmussen and Williams, 2006)](http://www.gaussianprocess.org/gpml). GPs are fully parametrised by a mean $\mu(x)$ and a covariance function $k(x,x')$.  Without loss of generality $\mu(x)$ is assumed to be zero. The covariance function $k(x,x')$ characterizes the smoothness and other properties of $f$. It is known as the
# kernel of the process and has to be continuous, symmetric and positive definite. A widely used kernel is the square exponential, given by
#
# $$ k(x,x') = l \cdot \exp{ \left(-\frac{\|x-x'\|^2}{2\sigma^2}\right)} $$
# where $\sigma^2$ and and $l$ are positive parameters.
#
# To denote that $f$ is a sample from a GP with mean $\mu$ and covariance $k$ we write
#
# $$f(x) \sim \mathcal{GP}(\mu(x),k(x,x')).$$
#
# For regression taks, the most important feature of GPs is that process priors are conjugate to the likelihood from finitely many observations $y= (y_1,\dots,y_n)^T$ and $X =\{x_1,...,x_n\}$, $x_i\in \mathcal{X}$ of the form $y_i = f(x_i) + \epsilon_i $
# where $\epsilon_i \sim \mathcal{N} (0,\sigma^2)$. We obtain the Gaussian posterior posterior $f(x^*)|X, y, \theta \sim \mathcal{N}(\mu(x^*),\sigma^2(x^*))$, where $\mu(x^*)$ and $\sigma^2(x^*)$ have close form. See [(Rasmussen and Williams, 2006)](http://www.gaussianprocess.org/gpml) for details.

# %% [markdown]
# ### 4.2 Acquisition Function
#
# Acquisition functions are designed represents our beliefs over the maximum of $f(x)$. Denote by $\theta$ the parameters of the GP model and by $\{x_i,y_i\}$ the available sample. Three of the most common acquisition functions, all available in GPyOpt are:
#
# * **Maximum probability of improvement (MPI)**:
#
# $$acqu_{MPI}(x;\{x_n,y_n\},\theta) = \Phi(\gamma(x)), \mbox{where}\   \gamma(x)=\frac{\mu(x;\{x_n,y_n\},\theta)-f(x_{best})-\psi}{\sigma(x;\{x_n,y_n\},\theta)}.$$
#
#
# * **Expected improvement (EI)**:
#
# $$acqu_{EI}(x;\{x_n,y_n\},\theta) = \sigma(x;\{x_n,y_n\},\theta) (\gamma(x) \Phi(\gamma(x))) + N(\gamma(x);0,1).$$
#
# * **Upper confidence bound (UCB)**:
#
# $$acqu_{UCB}(x;\{x_n,y_n\},\theta) = -\mu(x;\{x_n,y_n\},\theta)+\psi\sigma(x;\{x_n,y_n\},\theta).$$
#
# $\psi$ is a tunable parameters that help to make the acquisition functions more flexible. Also, in the case of the UBC, the parameter $\eta$ is useful to define the balance between the importance we give to the mean and the variance of the model. This is know as the **exploration/exploitation trade off**.

# %% [markdown]
# ### 4.3 Applications of Bayesian Optimization
#
# Bayesian Optimization has been applied to solve a wide range of problems. Among many other, some nice applications of Bayesian Optimization include:
#
#
# * Sensor networks (http://www.robots.ox.ac.uk/~parg/pubs/ipsn673-garnett.pdf),
#
# * Automatic algorithm configuration (http://www.cs.ubc.ca/labs/beta/Projects/SMAC/papers/11-LION5-SMAC.pdf),
#
# * Deep learning (http://www.mlss2014.com/files/defreitas_slides1.pdf),
#
# * Gene desing (http://bayesopt.github.io/papers/paper5.pdf),
#
# * and a long etc!
#
# In this Youtube video you can see Bayesian Optimization working in a real time in a robotics example. [(Calandra1 et al. 2008)](http://www.ias.tu-darmstadt.de/uploads/Site/EditPublication/Calandra_LION8.pdf)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ualnbKfkc3Q')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/ualnbKfkc3Q"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## 5. One dimensional example
#
# In this example we show how GPyOpt works in a one-dimensional example a bit more difficult that the one we analyzed in Section 3. Let's consider here the Forrester function
#
# $$f(x) =(6x-2)^2 \sin(12x-4)$$ defined on the interval $[0, 1]$.
#
# The minimum of this function is located at $x_{min}=0.78$. In this case we assume that the evaluations of $f$ to are perturbed by zero-mean Gaussian noise with standar deviation 0.25. The Forrester function is part of the benchmark of functions of GPyOpt. To create the true function, the perturbed version and boundaries of the problem you need to run the following cell.

# %%
# Create the true and perturbed Forrester function and the boundaries of the problem
f_true = GPyOpt.fmodels.experiments1d.forrester()             # true function
f_sim = GPyOpt.fmodels.experiments1d.forrester(sd= .25)       # noisy version
bounds = [(0,1)]                                              # problem constrains

# %% [markdown]
# We plot the true Forrester function.

# %%
f_true.plot(bounds)

# %% [markdown]
# As we did in Section 3, we need to create the GPyOpt object that will run the optimization. We specify the function, the boundaries and we add the type of acquisition function to use. The acquisition parameter (acquistion_par in the funcion input) is the $\psi$ parameter in Section 4.2.

# %%
# Creates GPyOpt object with the model and anquisition fucntion
seed(1234)
myBopt = GPyOpt.methods.BayesianOptimization(f=f_sim.f,            # function to optimize       
                                             bounds=bounds,        # box-constrains of the problem
                                             acquisition='EI',     # Selects the Expected improvement
                                             acquisition_par = 0)  # psi parameter is set to zero

# %% [markdown]
# Now we want to run the optimization. Appart from the number of iterations you can select
# how do you want to optimize the acquisition function. You can run a number of local optimizers (acqu_optimize_restart) at random or in grid (acqu_optimize_method).

# %%
# Run the optimization
max_iter = 15  # evaluation budget

myBopt.run_optimization(max_iter,                           # Number of iterations
                          acqu_optimize_method = 'fast_random',    # method to optimize the acq. function
                          acqu_optimize_restarts = 30,        # number of local optimizers 
                          stop_criteria=10e-6)                # secondary stop criteria
# Out:
# WARNING:root:Added 1 rounds of jitter, jitter of 3.6929857733e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.3497045862e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 5.0894199330e-06
# *Optimization completed:
#    -Maximum number of iterations reached.
# 1

# %% [markdown]
# When the optimization is done you should receive a message describing if the method converged or if the maximum number of iterations was reached. In one dimensional examples, you can see the result of the optimization as follows.

# %%
myBopt.plot_acquisition()

# %% [markdown]
# In problems of any dimension three evaluatios plots are available.
#
# * The distance between the last two observations.
#
# * The value of $f$ at the best location previous to each iteration.
#
# * The predicted standad deviation of each new location.
#
# To see these plots just run the following cell.

# %%
myBopt.plot_convergence()

# %% [markdown]
# Now let's make a video to track what the algorithm is doing in each iteration.

# %%
# starts the optimization 
iterBopt = GPyOpt.methods.BayesianOptimization(f=f_sim.f,                   
                                             bounds=bounds,
                                             acquisition='EI',
                                             acquisition_par = 0)

from IPython.display import clear_output
N_iter = 20

for i in range(N_iter):
    clear_output()
    seed(12345)
    iterBopt.run_optimization(max_iter=1, 
                          acqu_optimize_method = 'fast_brute',   # method to optimize the acquisition function
                          acqu_optimize_restarts = 100,          # number of local optimizers 
                          stop_criteria=10e-6)                   # secondary stop criteria
    iterBopt.plot_acquisition('iteration%.03i.png' % (i + 1))
# Out:
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6765346649e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5723473887e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1555982837e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5723194405e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5722265270e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.3639124054e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5718405797e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5705602914e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4672363484e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5516749493e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4951899658e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4518232286e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4832552737e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4889329453e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4707787688e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4176137401e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4130551682e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0886245088e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0866271688e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 8.8527725832e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.8430507207e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.6612398259e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.5426484933e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.6613592866e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.5789858764e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.6748482954e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.6957390979e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4197095412e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4197082354e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4197530522e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196765666e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4197340105e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196756460e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196749104e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196749103e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196749103e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196749103e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.9460366419e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6932792299e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4621667866e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 5.3843131312e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.7674917526e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5362757123e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4643427649e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4514572743e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.7941640880e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5505063703e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4743332010e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4539231942e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4525550244e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4519062866e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6090898498e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4997976771e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4642541662e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4535575931e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4513865583e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 3.1485851221e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0221906903e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6002899741e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6696814194e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6160818056e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5981458812e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6828418618e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6270106833e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6000393889e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.7043617668e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6437169836e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.9453777818e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6504934996e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5901741234e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.9963168213e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.6659923768e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5928535264e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5856113462e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5856113462e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5213575742e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 4.8342779245e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 4.1140602885e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5103177009e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0786067463e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0610836641e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7858059438e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.2346894145e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0844706548e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0613770074e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.7434446799e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5773785722e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.2009745453e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0871172151e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0624417496e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0609012329e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0607044821e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0606673758e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.2889572618e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.7971091606e-01
# WARNING:root:Added 1 rounds of jitter, jitter of 9.2343910937e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8264472758e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 4.9262007707e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0088126931e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9157350849e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.5602510025e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.2539824781e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.1100094168e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0402789766e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4984910327e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4812369733e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0412939404e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0060910678e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061447546e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0060617071e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061300343e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0060536981e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061259907e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061912228e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061671540e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061901266e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061911594e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061770314e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061904688e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061911616e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061911616e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0062196390e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061969029e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061916962e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061911682e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0061911616e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8710503990e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.9738467426e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.3783095245e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.5306599453e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.1873825852e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8999307016e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6503191630e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 5.1219132930e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.5309217493e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7839113654e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6354710006e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 7.4294284721e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 3.3570296766e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0661713248e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6966447233e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6296708708e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4824522240e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 3.7287990627e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.1990110710e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7375175074e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6347409531e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 8.5590260883e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 3.7556583962e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.2085952107e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7406282952e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6352222844e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6272434039e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196749103e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4196749103e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8504309592e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.0297616818e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612627e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8652780804e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8597611905e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594775688e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594621517e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594613112e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612653e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612628e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612628e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612628e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612628e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8594612628e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6681446712e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6517423610e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5861331205e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6517400916e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6517181724e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6189256464e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6437904970e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6486162748e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6450804238e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6376051109e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6430654488e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6448925175e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6320990841e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5875770865e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.3874590401e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.3857558245e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.2218697963e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.2193769402e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1825604900e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1645757796e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1556852518e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1529932128e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530200357e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530200366e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530120855e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530178043e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530195548e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530199898e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530200375e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1530200375e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 7.0247502151e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.7809793541e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.4644395687e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.1678602687e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.0265086779e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.9575348499e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5670598757e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 7.4075404983e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.7230934823e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.0253116307e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.9665929046e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.0425132946e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.1963696870e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.0189069051e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.9955302084e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.9990618416e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.9961659483e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.9955742474e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4355621176e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8159551113e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4504602236e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5618791039e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.3960309202e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1090503060e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8435658936e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1719686971e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1336735247e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1191420714e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1075449316e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1204532738e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1209567213e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0942274007e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0939383845e-04
# WARNING:root:Added 1 rounds of jitter, jitter of 9.2748256277e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 8.1559260896e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 8.1329511138e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 7.4256585325e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7842808563e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 9.1288192618e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 7.0765660506e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.9230694127e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 9.3674160374e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 7.1663035097e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7842337646e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 9.3830296196e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 7.1711778121e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7846487861e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.8063632905e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7833838341e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7773564574e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7836252771e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7742474166e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719485511e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467932e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467932e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467932e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467932e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467932e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7815727588e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719744590e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467935e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467935e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467935e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467935e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 7.1029913582e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7916196281e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7720540290e-06
# WARNING:root:Added 1 rounds of jitter, jitter of 6.7719467966e-06
# *Optimization completed:
#    -Maximum number of iterations reached.

# %%
# Import JSAnimation 
from JSAnimation import IPython_display, HTMLWriter
from matplotlib import animation
from PIL import Image
import glob

# Choose location of files to use
filenames=sorted(glob.glob('iteration*.png'))

#Create figure
fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
im = plt.imshow(Image.open(filenames[0]))

# Create initializatio function and animation
def init():
    im.set_data(Image.open(filenames[0]))
    return im,

def animate(i):
    image=Image.open(filenames[i])
    im.set_data(image)
    return im,

nframes = N_iter    # we create as many frames as iterations in the BO loop.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=nframes, interval=1000, blit=True)

# Show animation in ipython notebook
anim
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgXSIKTTUVZCKTDNYZ">
#     <br>
#     <input id="_anim_sliderXSIKTTUVZCKTDNYZ" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animXSIKTTUVZCKTDNYZ.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animXSIKTTUVZCKTDNYZ.slower()">&#8211;</button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animXSIKTTUVZCKTDNYZ.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectXSIKTTUVZCKTDNYZ" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgXSIKTTUVZCKTDNYZ";
#     var slider_id = "_anim_sliderXSIKTTUVZCKTDNYZ";
#     var loop_select_id = "_anim_loop_selectXSIKTTUVZCKTDNYZ";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animXSIKTTUVZCKTDNYZ = new Animation(frames, img_id, slider_id, 1000, loop_select_id);
#     }, 0);
#   })()
# </script>

# %% [markdown]
# ## 6. Two dimensional example
#
# Next, we try a 2-dimensional example. In this case we minimize the use the Six-hump camel function
#
# $$f(x_1,x_2) = \left(4-2.1x_1^2 = \frac{x_1^4}{3} \right)x_1^2 + x_1x_2 + (-4 +4x_2^2)x_2^2,$$
#
# in $[-3,3]\times [-2,2]$. This functions has two global minima, at $(0.0898,-0.7126)$ and $(-0.0898,0.7126)$. As in the previous case we create the function, which is already in GPyOpt.

# %%
# create the object function
f_true = GPyOpt.fmodels.experiments2d.sixhumpcamel()
f_sim = GPyOpt.fmodels.experiments2d.sixhumpcamel(sd = 0.1)
f_true.plot()
bounds = f_true.bounds

# %% [markdown]
# We create the GPyOpt object. In this case we use the Lower Confidence bound acquisition function to solve the problem.

# %%
# Creates three identical objects that we will later use to compare the optimization strategies 
myBopt2D = GPyOpt.methods.BayesianOptimization(f_sim.f,
                                              bounds=bounds,
                                              acquisition='LCB',   # Lower confidence bound method 
                                              acquisition_par = 2, # Set parameter psi=2 
                                              normalize = True)    # Normalize the acquisition funtction

# %% [markdown]
#  We run the optimization for 40 iterations and show the evaluation plot and the acquisition function.

# %%
# runs the optimization for the three methods
max_iter = 40

myBopt2D.run_optimization(max_iter,
                          acqu_optimize_method = 'fast_brute',  # lattice of initial points for local optimizers
                          acqu_optimize_restarts = 10,     # partition per dimension 
                          stop_criteria=1e-10)             # stop criteria (distance between consecutive observations)
# Out:
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8482200462e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.7968320256e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0307323986e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7090200959e-05
# *Optimization completed:
#    -Maximum number of iterations reached.
# 1

# %% [markdown]
# Finally, we plot the acquisition function and the convergence plot.

# %%
myBopt2D.plot_acquisition()

# %%
myBopt2D.plot_convergence()
