# %% [markdown]
# # GPyOpt: parallel Bayesian optimization
#
# ### Written by Javier Gonzalez, University of Sheffield.
#
# *Last updated Tuesday, 15 March 2016.*

# %% [markdown]
# In this noteboook we are going to learn how to use GPyOpt to run parallel BO methods. The goal of these approaches is to make use of all the computational power or our machine to perform the optimization. For instance, if we hace a computer with 4 cores, we may want to make 4 evaluations of $f$ in parallel everytime we test the performance of the algorithm.
#
# In this notebook we will use the **Local Penalization** method describe in the paper *Batch Bayesian Optimization via Local Penalization*.

# %%
from IPython.display import HTML 
HTML('<iframe src=http://arxiv.org/pdf/1505.08052v4.pdf width=700 height=550></iframe>')
# Out:
# <iframe src=http://arxiv.org/pdf/1505.08052v4.pdf width=700 height=550></iframe>

# %%
# %pylab inline  
import GPyOpt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# warning in stationary: failed to import cython module: falling back to numpy
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 21 days

# %% [markdown]
# As in previous examples we use a synthetic objective function but you can think about doing the same with any function you like. In this case, we use the Branin function. For the optimization we will perturb the evaluations with Gaussian noise with sd = 0.1.

# %%
# --- Objective function
objective_true  = GPyOpt.objective_examples.experiments2d.branin()                 # true function
objective_noisy = GPyOpt.objective_examples.experiments2d.branin(sd = 0.1)         # noisy version
bounds = objective_noisy.bounds

# %%
domain = [{'name': 'var_1', 'type': 'continuous', 'domain': bounds[0]}, ## use default bounds
          {'name': 'var_2', 'type': 'continuous', 'domain': bounds[1]}]

# %%
objective_true.plot()

# %% [markdown]
# As in previous cases, we create a GPyOpt object with the desing space and fucntion to optimize. In this case we need to select the evaluator type, which in this case is the *local penalization method* the batch size and the number of cores that we want to use. The evaluation of the function will be splitted accross the available cores.

# %%
batch_size = 4
num_cores = 4

# %%
from numpy.random import seed
seed(123)
BO_demo_parallel = GPyOpt.methods.BayesianOptimization(f=objective_noisy.f,  
                                            domain = domain,                  
                                            acquisition_type = 'EI',              
                                            normalize_Y = True,
                                            initial_design_numdata = 3,
                                            evaluator_type = 'local_penalization',
                                            batch_size = batch_size,
                                            num_cores = num_cores,
                                            acquisition_jitter = 0)
# Out:
# Optimization restart 1/5, f = 4.24442965481
# Optimization restart 2/5, f = 4.24442988052
# Optimization restart 3/5, f = 4.24442969088
# Optimization restart 4/5, f = 4.2444296352
# Optimization restart 5/5, f = 4.24442971427
# ** GPyOpt Bayesian Optimization class initialized succesfuly **

# %% [markdown]
# We will optimize this function by running 10 parallel evaluations in 3 cores of our machine.

# %%
# --- Run the optimization for 10 iterations
max_iter = 10                                                     
BO_demo_parallel.run_optimization(max_iter)
# Out:
# Optimization restart 1/5, f = -9.08071611256
# Optimization restart 2/5, f = -9.08071602663
# Optimization restart 3/5, f = -9.08071611255
# Optimization restart 4/5, f = -9.08071328281
# Optimization restart 5/5, f = -9.0807161125
# Optimization restart 1/5, f = -20.7870009946
# Optimization restart 2/5, f = -20.7870008828
# Optimization restart 3/5, f = -20.7870010107
# Optimization restart 4/5, f = -20.7870010107
# Optimization restart 5/5, f = -20.7869892924
# Optimization restart 1/5, f = -35.3736618031
# Optimization restart 2/5, f = -35.3736606987
# Optimization restart 3/5, f = -35.3736618027
# Optimization restart 4/5, f = -35.3736273106
# Optimization restart 5/5, f = -35.3736617991
# Optimization restart 1/5, f = -48.3174651932
# Optimization restart 2/5, f = -48.3174651822
# Optimization restart 3/5, f = -48.3174645429
# Optimization restart 4/5, f = -48.3174651743
# Optimization restart 5/5, f = -48.3174651937
# Optimization restart 1/5, f = -64.4495392736
# Optimization restart 2/5, f = -64.4495392687
# Optimization restart 3/5, f = -64.4495389072
# Optimization restart 4/5, f = -64.4495392729
# Optimization restart 5/5, f = -64.4495392736
# Optimization restart 1/5, f = -79.1213916348
# Optimization restart 2/5, f = -79.1213916343
# Optimization restart 3/5, f = -79.1213916181
# Optimization restart 4/5, f = -79.1213902097
# Optimization restart 5/5, f = -79.1213916325
# Optimization restart 1/5, f = -93.0572596734
# Optimization restart 2/5, f = -93.0572596715
# Optimization restart 3/5, f = -93.0572596741
# Optimization restart 4/5, f = -93.0572596751
# Optimization restart 5/5, f = -93.0572531419
# Optimization restart 1/5, f = -103.811290154
# Optimization restart 2/5, f = -103.811290168
# Optimization restart 3/5, f = -103.811290166
# Optimization restart 4/5, f = -103.811290167
# Optimization restart 5/5, f = -103.81129017
# Optimization restart 1/5, f = -112.732282986
# Optimization restart 2/5, f = -112.732274288
# Optimization restart 3/5, f = -112.732282989
# Optimization restart 4/5, f = -112.732283
# Optimization restart 5/5, f = -112.732282996
# Optimization restart 1/5, f = -118.783822837
# Optimization restart 2/5, f = -118.783822845
# Optimization restart 3/5, f = -118.783822833
# Optimization restart 4/5, f = -118.783822841
# Optimization restart 5/5, f = -118.78381638
# Optimization restart 1/5, f = -126.897581832
# Optimization restart 2/5, f = -126.897581815
# Optimization restart 3/5, f = -126.897581828
# Optimization restart 4/5, f = -126.897581844
# Optimization restart 5/5, f = -126.897581833
#    ** Maximum number of iterations reached **

# %% [markdown]
# We plot the resutls. Observe that the final number of evaluations that we will make is $10*4=40$.

# %%
BO_demo_parallel.plot_acquisition()

# %%
BO_demo_parallel.suggested_sample
# Out:
# array([[  3.29813697,   1.        ],
#        [  3.03426125,   2.06620923],
#        [ -3.01557796,  15.        ],
#        [  3.03250892,   2.17951741]])

# %% [markdown]
# See how the method explores the space using the four parallel evaluations of $f$ and it is able to identify the location of the three minima.

# %%
objective_noisy.min
# Out:
# [(-3.141592653589793, 12.275), (3.141592653589793, 2.275), (9.42478, 2.475)]
