# %% [markdown]
# ## Optimization with a mix of continuous and discrete variables

# %%
# %pylab inline
import GPyOpt
from numpy.random import seed
seed(1234)
        
# --- Fucntion to optimize
func  = GPyOpt.objective_examples.experiments2d.sixhumpcamel() 
#func  = GPyOpt.objective_examples.experiments1d.forrester() 

# --- Space design
space = GPyOpt.Design_space(space =[{'name': 'var_1', 'type': 'continuous', 'domain': (-1,1)},
                                    {'name': 'var_2', 'type': 'discrete', 'domain': (-1.5,0,.5,1)}])

# --- Objective
objective = GPyOpt.core.task.SingleObjective(func.f, space)

# --- CHOOSE the model type
model = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False)

# --- CHOOSE the acquisition optimizer
aquisition_optimizer = GPyOpt.optimization.AcquisitionOptimizer(space)

# --- CHOOSE the type of acquisition
acquisition = GPyOpt.acquisitions.AcquisitionEI(model, space, optimizer=aquisition_optimizer)

# --- CHOOSE the intial design
initial_design = GPyOpt.util.stats.initial_design('random', space, 5)

# BO object
bo = GPyOpt.core.BO(model, space, objective, acquisition, initial_design)

print '-----'
print '----- Running demo. It may take a few seconds.'
print '-----'

# --- Stop conditions
max_time  = None 
max_iter  = 5
tolerance = 1e-8     # distance between two consecutive observations  

# Run the optimization                                                  
bo.run_optimization(max_iter = max_iter, max_time = max_time, eps = tolerance, verbose=False) 
bo.plot_acquisition()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# -----
# ----- Running demo. It may take a few seconds.
# -----
# Optimization restart 1/5, f = -8.53395765606
# Optimization restart 2/5, f = -8.5339574253
# Optimization restart 3/5, f = -8.53395781134
# Optimization restart 4/5, f = -8.53395664778
# Optimization restart 5/5, f = -8.53395775016
# Optimization restart 1/5, f = -9.62175471774
# Optimization restart 2/5, f = -9.62175221505
# Optimization restart 3/5, f = -9.62174993657
# Optimization restart 4/5, f = -9.62175465451
# Optimization restart 5/5, f = -9.62175449889
# Optimization restart 1/5, f = -12.1338205746
# Optimization restart 2/5, f = -12.1338206426
# Optimization restart 3/5, f = -12.1338206598
# Optimization restart 4/5, f = -12.1337913898
# Optimization restart 5/5, f = -12.1338204822
# Optimization restart 1/5, f = -12.0352607732
# Optimization restart 2/5, f = -12.035255214
# Optimization restart 3/5, f = -12.0352558512
# Optimization restart 4/5, f = -12.0352607477
# Optimization restart 5/5, f = -12.0352608031
# Optimization restart 1/5, f = -12.5393178904
# Optimization restart 2/5, f = -12.5393174175
# Optimization restart 3/5, f = -12.539310039
# Optimization restart 4/5, f = -12.5393178531
# Optimization restart 5/5, f = -12.5393159223
# Optimization restart 1/5, f = -13.5433533906
# Optimization restart 2/5, f = -13.5433534394
# Optimization restart 3/5, f = -13.5433526361
# Optimization restart 4/5, f = -13.5433532205
# Optimization restart 5/5, f = -13.5433529386
