# %% [markdown]
# # GPyOpt: The tool for Bayesian Optimization
#
# ### Written by Javier Gonzalez (j.h.gonzalez@sheffield.ac.uk), University of Sheffield.
#
# ## Reference Manual index
#
# =====================================================================================================
# 1. **What is GPyOpt?**
#
# 2. **How to install GPyopt?**
#
# 3. **How to use GPyOpt?**
#     1. Gaussian Processes
#     2. Acquisition functions
#     3. Applications of Bayesian Optimization
#
# 4. **The Basics of Bayesian Optimization**
#
# 5. **1D optimization example**
#
# 6. **2D optimization example**
#
# =====================================================================================================

# %% [markdown]
# ## 1. What is GPyOpt?
#
# GPyOpt (http://sheffieldml.github.io/GPy/) is a tool for optimization (minimization) of black-box functions using Gaussian processes. It is based on GPy (http://sheffieldml.github.io/GPy/) and it has been implemented in Python 2.7 (https://www.python.org/download/releases/2.7/) by the group of Machine Learning (at SITraN) of the university of Sheffield (http://ml.dcs.shef.ac.uk/sitran/).
#
# These are the main features of GPyOPt:
#
# * You can perform Bayesian Optimization with **most common acquisition functions**, such as  Expected improvement (EI), Maximum probability of improvement (MPI) or the Upper confidence bound (GP-UCB).
#
#
# * **Any model available in GPy can used in GPyOpt** as a surrogate of the function to optimize. This includes a wide variety of kernel fuctions (and kernel combinations) and models such as Sparse Gaussian process, usefull to speed up computational costs in large scale scenarios. See GPy  https://gpy.readthedocs.org/en/latest/ for details.
#
#
# * GPyOpt allows you to run **parallel Bayesian optimization**. This is helpful when you want to perform simultaneously several evaluations of the function that you want to optimize.
#
#
# * You can use GPyOpt to **design physical experiments**. If you are, or if you work with, a wetlab person you can use GPyOpt to determine optimal strategies for sequential experimental designs.
#
#
# * GPyOpt contains a repository of **test functions for optimization **.
#
# =====================================================================================================

# %% [markdown]
# ## 2. How to install GPyOPt?
#
# The simplest way to install GPyOpt is using pip. Ubuntu users can do:
#
# ```sh
# sudo apt-get install python-pip
# pip install gpyopt
# ```
# =====================================================================================================

# %% [markdown]
# ## 3. How to use GPyOpt?

# %%
# %pylab inline  
import GPy
import GPyOpt
from numpy.random import seed
seed(12345)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# GPyOpt is easy to use as a black-box functions optimizer. To start you only need:
#
# * Your favorite function $f$ to minimize. We use $f(x)=2x^2$ in this toy example, whose global minimum is at x=0.

# %%
def myf(x):
    return (2*x)**2

# %% [markdown]
# * A set of box constrains, the interval [-1,1] in our case.

# %%
bounds = [(-1,1)]

# %% [markdown]
# * A budget, or number of allowed evaluations of $f$.

# %%
max_iter = 5

# %% [markdown]
# With this three pieces of information GPyOpt has enough to find the minimum of $f$ in the selected region. GPyOpt solves the problem in two steps. First, you need to create a GPyOpt object that stores the problem (f and and box-constrains). You can do it as follows.

# %%
myProblem = GPyOpt.methods.BayesianOptimization(myf,bounds)

# %% [markdown]
# Next you need to run the optimization for the given budget of iterations

# %%
myProblem.start_optimization(max_iter)
# Out:
#  /home/javier/workspace/GitHub/GPy/GPy/core/parameterization/transformations.py:70: RuntimeWarning:overflow encountered in exp
# WARNING:root:Added 1 rounds of jitter, jitter of 6.9039079549e+00
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0815107082e+01
# WARNING:root:Added 1 rounds of jitter, jitter of 2.1821392080e+01
# WARNING:root:Added 1 rounds of jitter, jitter of 4.1430652482e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.1436573023e+02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.5783117659e+02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.9169053025e+01
# WARNING:root:Added 1 rounds of jitter, jitter of 5.1991293558e+00
# WARNING:root:Added 1 rounds of jitter, jitter of 4.5607546889e+01
# WARNING:root:Added 1 rounds of jitter, jitter of 5.6034502517e+00
# WARNING:root:Added 1 rounds of jitter, jitter of 9.1217022486e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8641815809e+00
# WARNING:root:Added 1 rounds of jitter, jitter of 6.4482071305e-01
# WARNING:root:Added 1 rounds of jitter, jitter of 2.3890111475e-01
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0563716366e-01
# WARNING:root:Added 1 rounds of jitter, jitter of 5.3517696849e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 5.3517696970e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 5.3517696970e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 7.1856021065e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.9558361230e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4846008671e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0159209069e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4828226185e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0742448047e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4828553015e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.4828226185e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.2725691393e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 3.1963336973e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.3052639586e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.3010738887e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 3.2777648186e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6518649618e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6247102924e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6247102924e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6247102924e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6247103538e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 9.3567404610e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 4.3724651195e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0378256060e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 5.3958822999e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 3.1327578648e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9647749901e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9636507942e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1923511567e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.2398016636e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 4.2120562984e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8846401082e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0929523069e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.0556854069e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0832984961e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 5.7424407262e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 3.1726076018e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8900699193e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 2.1839864201e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8918762998e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895353540e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895353540e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895355679e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895363812e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895354958e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895354951e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895354951e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.8895354951e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 1.1014193108e-01
# WARNING:root:Added 1 rounds of jitter, jitter of 5.3412584791e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0076056003e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 3.2728438692e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9280087116e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9258324955e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9258324955e-02
# *Optimization completed:
#    -Maximum number of iterations reached.
# 1

# %% [markdown]
# After the selected iterations the problem is solved. You can access to the best found location $x^*$ by

# %%
myProblem.x_opt
# Out:
# array([-0.01650457])

# %% [markdown]
# and to the predicted value value of $f$ at $x^*$ optimum by

# %%
myProblem.fx_opt
# Out:
# array([ 0.0010896])

# %% [markdown]
# And that's it! Keep reading to learn how GPyOpt uses Bayesian Optimization to solve this an other optimization problem. You will also learn all the features and options that you can use to solve your problems efficiently.
#
# =====================================================================================================

# %% [markdown]
# ## 4. The Basics of Bayesian Optimization
#
# Bayesian optimization (BO) is an strategy for global optimization of black-box functions [(Snoek et al., 2012)](http://papers.nips.cc/paper/4522-practical-bayesian-optimization-of-machine-learning-algorithms.pdf). Let $f: {\mathcal X} \to R$ be a L-Lipschitz  continuous function defined on a compact subset ${\mathcal X} \subseteq R^d$. We are interested in solvig the global optimization problem of finding
# $$ x_{M} = \arg \min_{x \in {\mathcal X}} f(x). $$
#
# We assume that $f$ is a *black-box* from which only perturbed evaluations of the type $y_i = f(x_i) + \epsilon_i$, with $\epsilon_i \sim\mathcal{N}(0,\psi^2)$, are  available. The goal is to make a series of $x_1,\dots,x_N$ evaluations of $f$ such that the *cumulative regret*
# $$r_N= Nf(x_{M})- \sum_{n=1}^N f(x_n),$$
# is minimised. Essentially, $r_N$ is minimised if we start evaluating $f$ at $x_{M}$ as soon as possible.
#
# There are two crucial bits in any Bayesian Optimization (BO) procedure approach.
#
# 1. Define a **prior probability measure** on $f$: this function will capture the our prior beliefs on $f$. The prior will be updated to a 'posterior' using the available data.
#
# 2. Define an **acquisition function** $acqu(x)$: this is a criteria to decide where to sample next in order to gain the maximum information about the location of the global maximum of $f$.
#
# Everytime a new data point is collected. The model is reestimated and the acquisition function optimized again until convergence. Given a prior over the function $f$ and an acquisition function, a BO procedure will converge to the optimum of $f$ under some conditions [(Bull, 2011)](http://arxiv.org/pdf/1101.3501.pdf).

# %% [markdown]
# ### 4.1 Prior probability meassure on $f$: Gaussian processes

# %% [markdown]
# A Gaussian process (GP) is a probability distribution across classes functions, typically smooth, such that each linear finite-dimensional restriction is multivariate Gaussian [(Rasmussen and Williams, 2006)](http://www.gaussianprocess.org/gpml). GPs are fully parametrised by a mean $\mu(x)$ and a covariance function $k(x,x')$.  Without loss of generality $\mu(x)$ is assumed to be zero. The covariance function $k(x,x')$ characterizes the smoothness and other properties of $f$. It is known as the
# kernel of the process and has to be continuous, symmetric and positive definite. A widely used kernel is the square exponential, given by
#
# $$ k(x,x') = l \cdot \exp{ \left(-\frac{\|x-x'\|^2}{2\sigma^2}\right)} $$
# where $\sigma^2$ and and $l$ are positive parameters.
#
# To denote that $f$ is a sample from a GP with mean $\mu$ and covariance $k$ we write
#
# $$f(x) \sim \mathcal{GP}(\mu(x),k(x,x')).$$
#
# For regression taks, the most important feature of GPs is that process priors are conjugate to the likelihood from finitely many observations $y= (y_1,\dots,y_n)^T$ and $X =\{x_1,...,x_n\}$, $x_i\in \mathcal{X}$ of the form $y_i = f(x_i) + \epsilon_i $
# where $\epsilon_i \sim \mathcal{N} (0,\sigma^2)$. We obtain the Gaussian posterior posterior $f(x^*)|X, y, \theta \sim \mathcal{N}(\mu(x^*),\sigma^2(x^*))$, where $\mu(x^*)$ and $\sigma^2(x^*)$ have close form. See [(Rasmussen and Williams, 2006)](http://www.gaussianprocess.org/gpml) for details.

# %% [markdown]
# ### 4.2 Acquisition Function
#
# Acquisition functions are designed represents our beliefs over the maximum of $f(x)$. Denote by $\theta$ the parameters of the GP model and by $\{x_i,y_i\}$ the available sample. Three of the most common acquisition functions, all available in GPyOpt are:
#
# * **Maximum probability of improvement (MPI)**:
#
# $$acqu_{MPI}(x;\{x_n,y_n\},\theta) = \Phi(\gamma(x)), \mbox{where}\   \gamma(x)=\frac{\mu(x;\{x_n,y_n\},\theta)-f(x_{best})-\psi}{\sigma(x;\{x_n,y_n\},\theta)}.$$
#
#
# * **Expected improvement (EI)**:
#
# $$acqu_{EI}(x;\{x_n,y_n\},\theta) = \sigma(x;\{x_n,y_n\},\theta) (\gamma(x) \Phi(\gamma(x))) + N(\gamma(x);0,1).$$
#
# * **Upper confidence bound (UCB)**:
#
# $$acqu_{UCB}(x;\{x_n,y_n\},\theta) = -\mu(x;\{x_n,y_n\},\theta)+\psi\sigma(x;\{x_n,y_n\},\theta).$$
#
# $\psi$ is a tunable parameters that help to make the acquisition functions more flexible. Also, in the case of the UBC, the parameter $\eta$ is useful to define the balance between the importance we give to the mean and the variance of the model. This is know as the **exploration/exploitation trade off**.

# %% [markdown]
# ### 4.3 Applications of Bayesian Optimization
#
# Bayesian Optimization has been applied to solve a wide range of problems. Among many other, some nice applications of Bayesian Optimization include:
#
#
# * Sensor networks (http://www.robots.ox.ac.uk/~parg/pubs/ipsn673-garnett.pdf),
#
# * Automatic algorithm configuration (http://www.cs.ubc.ca/labs/beta/Projects/SMAC/papers/11-LION5-SMAC.pdf),
#
# * Deep learning (http://www.mlss2014.com/files/defreitas_slides1.pdf),
#
# * Gene desing (http://bayesopt.github.io/papers/paper5.pdf),
#
# * and a long etc!
#
# In this Youtube video you can see Bayesian Optimization working in a real time in a robotics example. [(Calandra1 et al. 2008)](http://www.ias.tu-darmstadt.de/uploads/Site/EditPublication/Calandra_LION8.pdf)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ualnbKfkc3Q')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/ualnbKfkc3Q"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## 5. One dimensional example
#
# In this example we show how GPyOpt works in a one-dimensional example a bit more difficult that the one we analyzed in Section 3. Let's consider here the Forrester function
#
# $$f(x) =(6x-2)^2 \sin(12x-4)$$ defined on the interval $[0, 1]$.
#
# The minimum of this function is located at $x_{min}=0.78$. In this case we assume that the evaluations of $f$ to are perturbed by zero-mean Gaussian noise with standar deviation 0.25. The Forrester function is part of the benchmark of functions of GPyOpt. To create the true function, the perturbed version and boundaries of the problem you need to run the following cell.

# %%
# Create the true and perturbed Forrester function and the boundaries of the problem
f_true = GPyOpt.fmodels.experiments1d.forrester()             # true function
f_sim = GPyOpt.fmodels.experiments1d.forrester(sd= .25)       # noisy version
bounds = [(0,1)]                                              # problem constrains

# %% [markdown]
# We plot the true Forrester function.

# %%
f_true.plot(bounds)

# %% [markdown]
# As we did in Section 3, we need to create the GPyOpt object that will run the optimization. We specify the function, the boundaries and we add the type of acquisition function to use. The acquisition parameter (acquistion_par in the funcion input) is the $\psi$ parameter in Section 4.2.

# %%
# Creates GPyOpt object with the model and anquisition fucntion
seed(1234)
myBopt = GPyOpt.methods.BayesianOptimization(f=f_sim.f,            # function to optimize       
                                             bounds=bounds,        # box-constrains of the problem
                                             acquisition='EI',     # Selects the Expected improvement
                                             acquisition_par = 0)  # psi parameter is set to zero

# %% [markdown]
# Now we want to run the optimization. Appart from the number of iterations you can select
# how do you want to optimize the acquisition function. You can run a number of local optimizers (acqu_optimize_restart) at random or in grid (acqu_optimize_method).

# %%
# Run the optimization
max_iter = 10  # evaluation budget

myBopt.start_optimization(max_iter,                           # Number of iterations
                          acqu_optimize_method = 'fast_random',    # method to optimize the acq. function
                          acqu_optimize_restarts = 25,        # number of local optimizers 
                          stop_criteria=10e-6)                # secondary stop criteria
# Out:
# WARNING:root:Added 1 rounds of jitter, jitter of 6.0158745162e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.7879934820e-02
# WARNING:root:Added 1 rounds of jitter, jitter of 9.9937148655e-03
# WARNING:root:Added 1 rounds of jitter, jitter of 2.3394995536e-03
# *Optimization completed:
#    -Maximum number of iterations reached.
# 1

# %% [markdown]
# When the optimization is done you should receive a message describing if the method converged or if the maximum number of iterations was reached. In one dimensional examples, you can see the result of the optimization as follows.

# %%
myBopt.plot_acquisition()

# %% [markdown]
# In problems of any dimension three evaluatios plots are available.
#
# * The distance between the last two observations.
#
# * The value of $f$ at the best location previous to each iteration.
#
# * The predicted standad deviation of each new location.
#
# To see these plots just run the following cell.

# %%
myBopt.plot_convergence()

# %% [markdown]
# Now let's make a video to track what the algorithm is doing in each iteration.

# %%
# starts the optimization 
iterBopt = GPyOpt.methods.BayesianOptimization(f=f_sim.f,                   
                                             bounds=bounds,
                                             acquisition='EI',
                                             acquisition_par = 0)

from IPython.display import clear_output
N_iter = 20

for i in range(N_iter):
    clear_output()
    seed(12345)
    iterBopt.start_optimization(max_iter=1, 
                          acqu_optimize_method = 'fast_brute',   # method to optimize the acquisition function
                          acqu_optimize_restarts = 100,          # number of local optimizers 
                          stop_criteria=10e-6)                   # secondary stop criteria
    iterBopt.plot_acquisition('iteration%.03i.png' % (i + 1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-8c3b4d50ad05> in <module>()
#      14                           acqu_optimize_method = 'fast_brute',   # method to optimize the acquisition function
#      15                           acqu_optimize_restarts = 100,          # number of local optimizers
# ---> 16                           stop_criteria=10e-6)                   # secondary stop criteria
#      17     iterBopt.plot_acquisition('iteration%.03i.png' % (i + 1))
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in start_optimization(self, max_iter, n_inbatch, acqu_optimize_method, batch_method, acqu_optimize_restarts, stop_criteria, n_procs, verbose)
#      61
#      62         # optimize model and acquisition function
# ---> 63         self._update_model()
#      64         prediction = self.model.predict(self.X)
#      65         self.m_in_min = prediction[0]
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _update_model(self)
#     207
#     208         # ------- Optimize acquisition function
# --> 209         self.suggested_sample = self._optimize_acquisition()
#     210
#     211
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/bo.pyc in _optimize_acquisition(self)
#     182         # ------ Selection of the batch method (if any, predictive used when n_inbathc=1)
#     183         if self.batch_method == 'predictive':
# --> 184             X_batch = predictive_batch_optimization(acqu_name, acquisition_par, acquisition, d_acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#     185         elif self.batch_method == 'mp':
#     186             X_batch = mp_batch_optimization(acquisition, d_acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.py in predictive_batch_optimization(acqu_name, acquisition_par, acquisition, d_acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, n_inbatch)
#      28     input_dim = X.shape[1]
#      29     kernel = model_copy.kern
# ---> 30     X_new = optimize_acquisition(acquisition, d_acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, X_batch=None, L=None, Min=None)
#      31     X_batch = reshape(X_new,input_dim)
#      32     k=1
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.py in optimize_acquisition(acquisition, d_acquisition, bounds, acqu_optimize_restarts, acqu_optimize_method, model, X_batch, L, Min)
#     111         res =  full_acquisition_optimization(acquisition, d_acquisition,bounds,acqu_optimize_restarts, model, 'random', X_batch, L, Min)
#     112     elif acqu_optimize_method=='fast_brute':
# --> 113         res =  fast_acquisition_optimization(acquisition, d_acquisition,bounds,acqu_optimize_restarts, model, 'brute', X_batch, L, Min)
#     114     elif acqu_optimize_method=='fast_random':
#     115         res =  fast_acquisition_optimization(acquisition, d_acquisition,bounds,acqu_optimize_restarts, model, 'random', X_batch, L, Min)
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/optimization.py in fast_acquisition_optimization(acquisition, d_acquisition, bounds, acqu_optimize_restarts, model, method_type, X_batch, L, Min)
#     129     h_func_args = hammer_function_precompute(X_batch, L, Min, model)
#     130     if X_batch==None:
# --> 131         res = scipy.optimize.minimize(acquisition, x0=np.array(x0),method='SLSQP',jac=d_acquisition,bounds=bounds, options = {'maxiter': 500})
#     132     else:
#     133         res = scipy.optimize.minimize(penalized_acquisition, x0=np.array(x0),method='SLSQP',bounds=bounds, args=(acquisition, bounds, model, X_batch)+h_func_args)
#
# /usr/lib/python2.7/dist-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     362     elif meth == 'slsqp':
#     363         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 364                                constraints, **options)
#     365     else:
#     366         raise ValueError('Unknown solver %s' % method)
#
# /usr/lib/python2.7/dist-packages/scipy/optimize/slsqp.pyc in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, **unknown_options)
#     372             # Compute the derivatives of the objective function
#     373             # For some reason SLSQP wants g dimensioned to n+1
# --> 374             g = append(fprime(x),0.0)
#     375
#     376             # Compute the normals of the constraints
#
# /usr/lib/python2.7/dist-packages/scipy/optimize/optimize.pyc in function_wrapper(x)
#     259     def function_wrapper(x):
#     260         ncalls[0] += 1
# --> 261         return function(x, *args)
#     262     return ncalls, function_wrapper
#     263
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/core/acquisition.pyc in d_acquisition_function(self, x)
#      36                 Derivative of the Expected Improvement (has a very easy derivative!)
#      37 		"""
# ---> 38                 m, s, fmin, dmdx, dsdx = get_moments(self.model, x)
#      39                 phi, Phi, _ = get_quantiles(self.acquisition_par, fmin, m, s)
#      40                 df_acqu = dsdx * phi - Phi * dmdx
#
# /home/javier/workspace/GitHub/GPyOpt/GPyOpt/util/general.pyc in get_moments(model, x)
#      55     x = reshape(x,input_dim)
#      56     fmin = min(model.predict(model.X)[0])
# ---> 57     m, v = model.predict(x)
#      58     dmdx, dvdx = model.predictive_gradients(x)
#      59     s = np.sqrt(np.clip(v, 0, np.inf))
#
# /home/javier/workspace/GitHub/GPy/GPy/core/gp.pyc in predict(self, Xnew, full_cov, Y_metadata, kern)
#     216         """
#     217         #predict the latent function values
# --> 218         mu, var = self._raw_predict(Xnew, full_cov=full_cov, kern=kern)
#     219         if self.normalizer is not None:
#     220             mu, var = self.normalizer.inverse_mean(mu), self.normalizer.inverse_variance(var)
#
# /home/javier/workspace/GitHub/GPy/GPy/core/gp.pyc in _raw_predict(self, _Xnew, full_cov, kern)
#     180             kern = self.kern
#     181
# --> 182         Kx = kern.K(_Xnew, self.X).T
#     183         WiKx = np.dot(self.posterior.woodbury_inv, Kx)
#     184         mu = np.dot(Kx.T, self.posterior.woodbury_vector)
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      63     def wrap(self, X, X2 = None, *a, **kw):
#      64         with _Slice_wrap(self, X, X2) as s:
# ---> 65             ret = f(self, s.X, s.X2, *a, **kw)
#      66         return ret
#      67     return wrap
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     180         except KeyError:
#     181             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 182         return cacher(*args, **kwargs)
#     183
#     184 class Cache_this(object):
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     106             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     107             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 108             return self.operation(*args, **kw)
#     109         # 3&4: check whether this cache_id has been cached, then has it changed?
#     110         try:
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/add.pyc in K(self, X, X2, which_parts)
#      36             # if only one part is given
#      37             which_parts = [which_parts]
# ---> 38         return reduce(np.add, (p.K(X, X2) for p in which_parts))
#      39
#      40     @Cache_this(limit=2, force_kwargs=['which_parts'])
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/add.pyc in <genexpr>((p,))
#      36             # if only one part is given
#      37             which_parts = [which_parts]
# ---> 38         return reduce(np.add, (p.K(X, X2) for p in which_parts))
#      39
#      40     @Cache_this(limit=2, force_kwargs=['which_parts'])
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      63     def wrap(self, X, X2 = None, *a, **kw):
#      64         with _Slice_wrap(self, X, X2) as s:
# ---> 65             ret = f(self, s.X, s.X2, *a, **kw)
#      66         return ret
#      67     return wrap
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     180         except KeyError:
#     181             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 182         return cacher(*args, **kwargs)
#     183
#     184 class Cache_this(object):
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     106             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     107             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 108             return self.operation(*args, **kw)
#     109         # 3&4: check whether this cache_id has been cached, then has it changed?
#     110         try:
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/stationary.pyc in K(self, X, X2)
#      80         K(X, X2) = K_of_r((X-X2)**2)
#      81         """
# ---> 82         r = self._scaled_dist(X, X2)
#      83         return self.K_of_r(r)
#      84
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     180         except KeyError:
#     181             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 182         return cacher(*args, **kwargs)
#     183
#     184 class Cache_this(object):
#
# /home/javier/workspace/GitHub/GPy/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     106             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     107             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 108             return self.operation(*args, **kw)
#     109         # 3&4: check whether this cache_id has been cached, then has it changed?
#     110         try:
#
# /home/javier/workspace/GitHub/GPy/GPy/kern/_src/stationary.pyc in _scaled_dist(self, X, X2)
#     125             return self._unscaled_dist(X/self.lengthscale, X2)
#     126         else:
# --> 127             return self._unscaled_dist(X, X2)/self.lengthscale
#     128
#     129     def Kdiag(self, X):
#
# /home/javier/workspace/GitHub/GPy/GPy/core/parameterization/param.pyc in __array_finalize__(self, obj)
#      83         self._realndim_ = getattr(obj, '_realndim_', None)
#      84         self._original_ = getattr(obj, '_original_', None)
# ---> 85         self._name = getattr(obj, '_name', None)
#      86         self._gradient_array_ = getattr(obj, '_gradient_array_', None)
#      87         self._update_on = getattr(obj, '_update_on', None)
#
# KeyboardInterrupt:

# %%
# Import JSAnimation 
from JSAnimation import IPython_display, HTMLWriter
from matplotlib import animation
from PIL import Image
import glob

# Choose location of files to use
filenames=sorted(glob.glob('iteration*.png'))

#Create figure
fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
im = plt.imshow(Image.open(filenames[0]))

# Create initializatio function and animation
def init():
    im.set_data(Image.open(filenames[0]))
    return im,

def animate(i):
    image=Image.open(filenames[i])
    im.set_data(image)
    return im,

nframes = N_iter    # we create as many frames as iterations in the BO loop.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=nframes, interval=1000, blit=True)

# Show animation in ipython notebook
anim
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgDHGMTLLZGHXSCKFS">
#     <br>
#     <input id="_anim_sliderDHGMTLLZGHXSCKFS" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animDHGMTLLZGHXSCKFS.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animDHGMTLLZGHXSCKFS.slower()">&#8211;</button>
#     <button onclick="animDHGMTLLZGHXSCKFS.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDHGMTLLZGHXSCKFS.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectDHGMTLLZGHXSCKFS" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgDHGMTLLZGHXSCKFS";
#     var slider_id = "_anim_sliderDHGMTLLZGHXSCKFS";
#     var loop_select_id = "_anim_loop_selectDHGMTLLZGHXSCKFS";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animDHGMTLLZGHXSCKFS = new Animation(frames, img_id, slider_id, 1000, loop_select_id);
#     }, 0);
#   })()
# </script>

# %% [markdown]
# ## 6. Two dimensional example
#
# Next, we try a 2-dimensional example. In this case we minimize the use the Six-hump camel function
#
# $$f(x_1,x_2) = \left(4-2.1x_1^2 = \frac{x_1^4}{3} \right)x_1^2 + x_1x_2 + (-4 +4x_2^2)x_2^2,$$
#
# in $[-3,3]\times [-2,2]$. This functions has two global minima, at $(0.0898,-0.7126)$ and $(-0.0898,0.7126)$. As in the previous case we create the function, which is already in GPyOpt.

# %%
# create the object function
f_true = GPyOpt.fmodels.experiments2d.sixhumpcamel()
f_sim = GPyOpt.fmodels.experiments2d.sixhumpcamel(sd = 0.1)
f_true.plot()
bounds = f_true.bounds

# %% [markdown]
# We create the GPyOpt object. In this case we use the Lower Confidence bound acquisition function to solve the problem.

# %%
# Creates three identical objects that we will later use to compare the optimization strategies 
myBopt2D = GPyOpt.methods.BayesianOptimization(f_sim.f,
                                              bounds=bounds,
                                              acquisition='LCB',   # Lower confidence bound method 
                                              acquisition_par = 2, # Set parameter psi=2 
                                              normalize = True)    # Normalize the acquisition funtction

# %% [markdown]
#  We run the optimization for 40 iterations and show the evaluation plot and the acquisition function.

# %%
# runs the optimization for the three methods
max_iter = 40

myBopt2D.start_optimization(max_iter,
                          acqu_optimize_method = 'fast_brute',  # lattice of initial points for local optimizers
                          acqu_optimize_restarts = 10,     # partition per dimension 
                          stop_criteria=1e-10)             # stop criteria (distance between consecutive observations)
# Out:
# WARNING:root:Added 1 rounds of jitter, jitter of 5.8396329349e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.0677249310e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9093654746e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6334745771e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6098667713e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6001719554e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0322823575e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7111693491e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6426710015e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0552358792e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7162544017e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6480854939e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6458432350e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6282401467e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6116037177e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6059848380e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6017144249e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6006001724e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6001318731e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.6445429833e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.7769424047e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6089529264e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6056567487e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6022133587e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.8838017909e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.1128375639e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6588333531e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6004829885e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 1.6024016976e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 6.0675776619e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.7973351181e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8981957899e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0600309634e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4645940654e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4650957336e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4640193016e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4617265524e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4177222951e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4363987444e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4440695881e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4418357728e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4396048683e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4484300708e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4456973029e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.4464785381e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0515478795e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.7958757919e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.7824816345e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.6667535174e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.4532069188e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.4288234307e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0097034586e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 3.0001506717e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9998604074e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9920677369e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9644444183e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8699710294e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 4.3370954474e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9615010623e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9009609891e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8345357731e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8468339342e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8548220788e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8600399226e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8650360628e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8675173585e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8683595775e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9997738275e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8738424162e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8903051593e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8827951183e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8764755698e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8754042877e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8743654581e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.9340297652e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8753495636e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8743405932e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8738367301e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8635020817e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8726192813e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8728603284e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8730187170e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8731710323e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8643511305e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8729276183e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 2.8733224629e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.9722880179e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.9846947911e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 9.0343218875e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 9.1834801616e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 9.1357132602e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.9446456619e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.9241702766e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.4423092644e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.3538656648e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.3377546169e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.6375656065e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.7612019318e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.8406454235e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.8921791276e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.3266379060e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.5242124453e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.6521146774e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.7731917969e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.8141050303e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.8534941989e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 8.0088998720e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.8961123972e-05
# WARNING:root:Added 1 rounds of jitter, jitter of 7.9000300163e-05

# %% [markdown]
# Finally, we plot the acquisition function and the convergence plot.

# %%
myBopt2D.plot_acquisition()

# %%
myBopt2D.plot_convergence()
